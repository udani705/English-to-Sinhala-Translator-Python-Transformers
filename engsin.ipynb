# %%
# !pip install panda
import pandas as pd
import random
import tensorflow as tf
import string
import re
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# Collecting panda
#   Downloading panda-0.3.1.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from panda) (67.7.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from panda) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->panda) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->panda) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->panda) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->panda) (2024.2.2)
# Building wheels for collected packages: panda
#   Building wheel for panda (setup.py) ... done
#   Created wheel for panda: filename=panda-0.3.1-py3-none-any.whl size=7239 sha256=df267918308e5e5101fb87539aa168bfa18e28d84e0d3c2864b7ee737a919c42
#   Stored in directory: /root/.cache/pip/wheels/0e/8b/c3/ff9cbde1fffd8071cff8367a86f0350a1ce30a8d31b6a432e9
# Successfully built panda
# Installing collected packages: panda
# Successfully installed panda-0.3.1

# %% [markdown]
# #Mount G-Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Loading the Dataset

# %%
path = '/content/drive/MyDrive/CSV/englishsinhala.txt'
df = pd.read_table(path, sep="\t")

# %% [markdown]
# #Read the data file

# %%
text_file = "/content/drive/MyDrive/CSV/englishsinhala.txt"
try:
    with open(text_file, 'r', encoding='utf-8') as f:
        lines = f.readlines()
except Exception as e:
    print("Error:", e)


for line in lines[:20]:
    print(line.strip())
# Out:
# english	sinhala
# Go.	යන්න.
# Go.	යන්න.
# Go.	යන්න.
# Go.	යන්න.
# Hi.	ආයුබෝවන්.
# Run!	දුවන්න!
# Run.	දුවන්න.
# Who?	WHO?
# Fire!	ගිනි!
# Fire!	ගිනි!
# Fire!	ගිනි!
# Help!	උදව්!
# Help!	උදව්!
# Help!	උදව්!
# Jump!	පනින්න!
# Jump.	පනින්න.
# Stop!	නවත්වන්න!
# Stop!	නවත්වන්න!
# Stop!	නවත්වන්න!

# %%
for line in lines[-10:]:
    print(line.strip())
# Out:
# In 1969, Roger Miller recorded a song called "You Don't Want My Love." Today, this song is better known as "In the Summer Time." It's the first song he wrote and sang that became popular.	1969 දී රොජර් මිලර් "ඔබට මගේ ආදරය අවශ්‍ය නැත" නමින් ගීතයක් පටිගත කළේය." අද මෙම ගීතය වඩාත් හොඳින් හඳුන්වනු ලබන්නේ "ගිම්හාන කාලය තුළ" යනුවෙනි." ඔහු ලියූ සහ ගායනා කළ පළමු ගීතය එය ජනප්‍රිය විය.
# A child who is a native speaker usually knows many things about his or her language that a non-native speaker who has been studying for years still does not know and perhaps will never know.	ස්වදේශික කථිකයෙකු වන දරුවෙකු සාමාන්‍යයෙන් ඔහුගේ හෝ ඇයගේ භාෂාව ගැන බොහෝ දේ දන්නා අතර වසර ගණනාවක් ඉගෙන ගන්නා ස්වදේශික නොවන කථිකයෙකු තවමත් නොදන්නා අතර සමහර විට කිසි විටෙකත් නොදනී.
# There are four main causes of alcohol-related death. Injury from car accidents or violence is one. Diseases like cirrhosis of the liver, cancer, heart and blood system diseases are the others.	මත්පැන් ආශ්‍රිත මරණයට ප්‍රධාන හේතු හතරක් තිබේ. රිය අනතුරු හෝ ප්‍රචණ්ඩත්වයෙන් සිදුවන තුවාල එකකි. අක්මාවේ සිරෝසිස්, පිළිකා, හෘද හා රුධිර පද්ධතියේ රෝග වැනි රෝග අනෙක් ඒවා වේ.
# There are mothers and fathers who will lie awake after the children fall asleep and wonder how they'll make the mortgage, or pay their doctor's bills, or save enough for their child's college education.	දරුවන් නින්දට ගිය පසු අවදියෙන් වැතිර සිටින මව්වරුන් සහ පියවරුන් සිටින අතර ඔවුන් උකස සාදා ගන්නේ කෙසේද, නැතහොත් ඔවුන්ගේ වෛද්‍යවරයාගේ බිල්පත් ගෙවන්නේ කෙසේද, නැතහොත් තම දරුවාගේ විද්‍යාල අධ්‍යාපනය සඳහා ප්‍රමාණවත් මුදලක් ඉතිරි කරන්නේ කෙසේදැයි කල්පනා කරති.
# A carbon footprint is the amount of carbon dioxide pollution that we produce as a result of our activities. Some people try to reduce their carbon footprint because they are concerned about climate change.	කාබන් පියසටහනක් යනු අපගේ ක්‍රියාකාරකම්වල ප්‍රතිඵලයක් ලෙස අප නිපදවන කාබන් ඩයොක්සයිඩ් දූෂණයේ ප්‍රමාණයයි. සමහර අය දේශගුණික විපර්යාස ගැන සැලකිලිමත් වන නිසා ඔවුන්ගේ කාබන් පියසටහන අඩු කිරීමට උත්සාහ කරති.
# Since there are usually multiple websites on any given topic, I usually just click the back button when I arrive on any webpage that has pop-up advertising. I just go to the next page found by Google and hope for something less irritating.	ඕනෑම මාතෘකාවක සාමාන්‍යයෙන් වෙබ් අඩවි කිහිපයක් ඇති බැවින්, මම සාමාන්‍යයෙන් උත්පතන වෙළඳ දැන්වීම් ඇති ඕනෑම වෙබ් පිටුවකට පැමිණෙන විට පසුපස බොත්තම ක්ලික් කරමි. මම ගූගල් විසින් සොයාගත් ඊළඟ පිටුවට ගොස් අඩු කෝපයක් ඇති කිරීමට බලාපොරොත්තු වෙමි.
# If you want to sound like a native speaker, you must be willing to practice saying the same sentence over and over in the same way that banjo players practice the same phrase over and over until they can play it correctly and at the desired tempo.	ඔබට ස්වදේශික කථිකයෙකු ලෙස ශබ්ද කිරීමට අවශ්‍ය නම්, බැන්ජෝ ක්‍රීඩකයින් එකම වාක්‍ය ඛණ්ඩය නිවැරදිව සහ අපේක්ෂිත ටෙම්පෝවෙන් වාදනය කරන තෙක් එකම වාක්‍ය ඛණ්ඩය නැවත නැවතත් පුහුණු කරන ආකාරයටම එකම වාක්‍යය නැවත නැවතත් පැවසීමට ඔබ කැමති විය යුතුය.

# %% [markdown]
# #Identify the structure

# %%
for line in lines:
    print(line.strip())
# Out:
# Streaming output truncated to the last 5000 lines.
# They came to make peace.	ඔවුන් ආවේ සාමය ඇති කරන්න.
# They chased others away.	ඔවුන් අන් අයව එළවා දැමුවා.
# They didn't act quickly.	ඔවුන් ඉක්මනින් ක්රියා කළේ නැත.
# They didn't make a deal.	ඔවුන් ගනුදෙනුවක් කළේ නැහැ.
# They didn't mistreat me.	ඔවුන් මට හිරිහැර කළේ නැහැ.
# They do nothing but cry.	ඔවුන් අඬනවා හැර වෙන කිසිවක් කරන්නේ නැත.
# They don't know my name.	මගේ නම දන්නේ නෑ.
# They don't speak French.	ඔවුන් ප්රංශ භාෂාව කතා කරන්නේ නැහැ.
# They enjoyed themselves.	ඔවුන් විනෝද වුණා.
# They entered cautiously.	ඔවුන් ප්රවේශමෙන් ඇතුළු විය.
# They entered cautiously.	ඔවුන් ප්රවේශමෙන් ඇතුළු විය.
# They entered cautiously.	ඔවුන් ප්රවේශමෙන් ඇතුළු විය.
# They entered cautiously.	ඔවුන් ප්රවේශමෙන් ඇතුළු විය.
# They entered cautiously.	ඔවුන් ප්රවේශමෙන් ඇතුළු විය.
# They flattened his nose.	ඔවුන් ඔහුගේ නාසය සමතලා කළා.
# They fought for freedom.	ඔවුන් නිදහස වෙනුවෙන් සටන් කළා.
# They freed the prisoner.	ඔවුන් සිරකරුවා නිදහස් කළා.
# They got out of the car.	ඔවුන් කාර් එකෙන් එළියට ආවා.
# They had a pillow fight.	ඔවුන් කොට්ට සටනක් කළා.
# They had good chemistry.	හොඳ රසායන විද්යාව තිබුණා.
# They had no place to go.	ඔවුන්ට යන්න තැනක් තිබුණේ නැහැ.
# They have a large house.	ඔවුන්ට විශාල නිවසක් ඇත.
# They have already begun.	දැනටමත් ඒවා පටන්ගෙන.
# They have two daughters.	ඔවුන්ට දියණියන් දෙදෙනෙක් සිටී.
# They know what happened.	උන් දන්නවා වෙච්ච දේ.
# They know what happened.	උන් දන්නවා වෙච්ච දේ.
# They lived a happy life.	ඔවුන් සතුටින් ජීවත් වුණා.
# They lived a happy life.	ඔවුන් සතුටින් ජීවත් වුණා.
# They met in high school.	ඔවුන් හමුවුනේ උසස් පාසලෙදි.
# They moved ahead slowly.	ඔවුන් හෙමින් ඉදිරියට ගියා.
# They must've been tired.	ඔවුන් වෙහෙසට පත්ව සිටිය යුතුය.
# They must've been tired.	ඔවුන් වෙහෙසට පත්ව සිටිය යුතුය.
# They never listen to me.	ඔවුන් කවදාවත් මට ඇහුම්කන් දෙන්නේ නැහැ.
# They refused to help us.	ඔවුන් අපට උදව් කිරීම ප්රතික්ෂේප කළා.
# They require extra help.	ඔවුන්ට අමතර උදව් අවශ්ය වෙනවා.
# They say he's very rich.	එයා ගොඩක් පොහොසත් කියලා කියනවා.
# They sell fish and meat.	ඔවුන් මාළු සහ මස් විකුණනවා.
# They shot him yesterday.	ඊයේ ඔහුට වෙඩි තැබුවා.
# They think we're a gang.	එයාලා හිතන්නේ අපි කල්ලියක් කියලා.
# They took off after Tom.	ඔවුන් ටොම්ගෙන් පසුව පිටත් විය.
# They took our passports.	ඔවුන් අපේ ගමන් බලපත්ර ගත්තා.
# They went up the stairs.	ඔවුන් පඩිපෙළ නැගලා ගියා.
# They were put in prison.	ඔවුන්ව හිරේ දැම්මා.
# They were very confused.	ඔවුන් ඉතා ව්යාකූල විය.
# They will agree on that.	ඔවුන් ඒ ගැන එකඟ වෙයි.
# They will never find us.	එයාල කවදාවත් අපිව හොයාගන්නේ නෑ.
# They're all chasing Tom.	ඔවුන් සියල්ලෝම ටොම් පසුපස හඹා යති.
# They're always fighting.	ඔවුන් හැමවිටම සටන් කරනවා.
# They're always together.	ඔවුන් හැමවිටම එකට ඉන්නවා.
# They're looking for Tom.	ඔවුන් ටොම්ව හොයනවා.
# They're looking for you.	ඔවුන් ඔයාව හොයනවා.
# They're looking for you.	ඔවුන් ඔයාව හොයනවා.
# They're not coming back.	එයාලා ආපහු එන්නේ නෑ.
# They're right behind me.	ඔවුන් මගේ පිටුපසින්.
# They're speaking French.	ඔවුන් කතා කරන්නේ ප්රංශ.
# They're taking pictures.	ඔවුන් පින්තූර ගන්නවා.
# They're waiting for you.	ඔවුන් ඔබ එනතුරු බලා සිටිනවා.
# They're waiting outside.	ඔවුන් පිටත බලා සිටිනවා.
# Things are looking good.	දේවල් හොඳ පෙනුමක්.
# Think about your future.	ඔබේ අනාගතය ගැන හිතන්න.
# Think about your future.	ඔබේ අනාගතය ගැන හිතන්න.
# Think about your future.	ඔබේ අනාගතය ගැන හිතන්න.
# This account is correct.	මේ ගිණුම නිවැරදියි.
# This animal is friendly.	මේ සතා මිත්රශීලීයි.
# This battery is charged.	මෙම බැටරිය ආරෝපණය වේ.
# This bolt fits this nut.	මෙම බෝල්ට් මෙම ගෙඩියට ගැලපේ.
# This book belongs to me.	මේ පොත අයිති මට.
# This book is a whodunit.	මෙම පොත හූඩුනිට් ය.
# This book is really old.	මේ පොත ඇත්තටම පරණයි.
# This book is very heavy.	මේ පොත ගොඩක් බරයි.
# This book is very small.	මේ පොත බොහොම පොඩියි.
# This box is made of tin.	මේ පෙට්ටිය හදලා තියෙන්නේ ටින් වලින්.
# This bread is delicious.	මේ පාන් හරිම රසයි.
# This car is my father's.	මේ කාර් එක මගේ තාත්තගෙ.
# This changes everything.	මේකෙන් හැමදේම වෙනස් වෙනවා.
# This could be dangerous.	මෙය අනතුරුදායක විය හැකිය.
# This dictionary is mine.	මේ ශබ්දකෝෂය මගේ.
# This discussion is over.	මේ සාකච්ඡාව ඉවරයි.
# This does not bode well.	මෙය හොඳ නැත.
# This does not bode well.	මෙය හොඳ නැත.
# This door will not open.	මේ දොර අරින්නෙ නෑ.
# This flower smells nice.	මේ මල හොඳට සුවඳයි.
# This food smells rotten.	මේ ආහාරයේ සුවඳ දිරා යයි.
# This hat doesn't fit me.	මේ තොප්පිය මට ගැලපෙන්නේ නෑ.
# This heat is unbearable.	මෙම තාපය දරාගත නොහැක.
# This house is very good.	මේ ගෙදර හරිම හොඳයි.
# This is a Japanese doll.	මේ ජපන් බෝනික්කෙක්.
# This is a Japanese doll.	මේ ජපන් බෝනික්කෙක්.
# This is a gorgeous town.	මේක ලස්සන නගරයක්.
# This is a terrible idea.	මේක භයානක අදහසක්.
# This is a very good tea.	මේක හොඳ තේ එකක්.
# This is a very new book.	මේක බොහොම අලුත් පොතක්.
# This is a very old book.	මේක බොහොම පරණ පොතක්.
# This is a very old book.	මේක බොහොම පරණ පොතක්.
# This is all that I know.	එච්චරයි මම දන්නේ.
# This is by far the best.	මෙය බොහෝ දුරට හොඳම ය.
# This is going perfectly.	මේක හොඳටම යනවා.
# This is his only chance.	මේ ඔහුගේ එකම අවස්ථාවයි.
# This is how I cook fish.	ඒ විදියට තමයි මම මාළු උයන්නේ.
# This is how it happened.	එහෙම තමයි මේක වුණේ.
# This is just my opinion.	මේක මගේ අදහස විතරයි.
# This is my new tricycle.	මේ මගේ අලුත් ත්‍රිරෝද රථය.
# This is not a good idea.	මේක හොඳ අදහසක් නෙවෙයි.
# This is not about money.	මේක සල්ලි ගැන නෙමෙයි.
# This is not about money.	මේක සල්ලි ගැන නෙමෙයි.
# This is not good at all.	මේක කොහෙත්ම හොඳ නෑ.
# This is our last chance.	මේ අපේ අන්තිම අවස්ථාව.
# This is the ticket line.	මේක තමයි ටිකට් ලයින් එක.
# This is why I fired him.	ඒකයි මම එයාව අයින් කලේ.
# This is your big chance.	මේක ඔයාගේ ලොකු අවස්ථාවක්.
# This isn't so difficult.	මේක එච්චර අමාරු දෙයක් නෙවෙයි.
# This isn't the only key.	මේක එකම යතුර නෙමෙයි.
# This might interest you.	මෙය ඔබට උනන්දුවක් විය හැකිය.
# This orange is too sour.	මේ තැඹිලි පාට වැඩියි.
# This place is beautiful.	මේ තැන ලස්සනයි.
# This problem baffles me.	මේ ප්රශ්නය මාව අවුල් කරනවා.
# This problem baffles me.	මේ ප්රශ්නය මාව අවුල් කරනවා.
# This reminds me of home.	මේක මට ගෙදර මතක් කරනවා.
# This river is beautiful.	මේ ගඟ හරිම ලස්සනයි.
# This room gets sunshine.	මේ කාමරයට හිරු එළිය ලැබෙනවා.
# This shop belongs to me.	මේ කඩේ අයිති මට.
# This situation is funny.	මේ තත්ත්වය විහිළුවක්.
# This situation is funny.	මේ තත්ත්වය විහිළුවක්.
# This smells like cheese.	ඒක චීස් වගේ සුවඳක්.
# This sounds interesting.	මෙය සිත්ගන්නා සුළුය.
# This sounds like French.	මේක ප්රංශ වගේ.
# This sounds like a trap.	මේක උගුලක් වගේ.
# This sounds like a trap.	මේක උගුලක් වගේ.
# This steak is too tough.	මේ ස්ටීක් එක ගොඩක් අමාරුයි.
# This table isn't steady.	මේ වගුව ස්ථිර නැහැ.
# This thing terrifies me.	මේ දේ මාව බය කරනවා.
# This turkey tastes good.	මේ තුර්කිය රසයි.
# This was all Tom's idea.	ටොම්ගේ අදහස මෙයයි.
# This watch is expensive.	මේ ඔරලෝසුව මිල අධිකයි.
# This will keep you warm.	එය ඔබව උණුසුම් කරයි.
# This will keep you warm.	එය ඔබව උණුසුම් කරයි.
# This won't happen again.	මෙය නැවත සිදු නොවනු ඇත.
# This would be a mistake.	ඒක වැරදීමක්.
# Those flowers have died.	ඒ මල් මැරිලා.
# Those flowers have died.	ඒ මල් මැරිලා.
# Those things disgust me.	ඒ දේවල් මාව පිළිකුල් කරනවා.
# Three of these are mine.	මේ තුන්දෙනා මගේ.
# Three of these are mine.	මේ තුන්දෙනා මගේ.
# Today I had a math test.	අද මට ගණිත පරීක්ෂණයක් තියෙනවා.
# Today is a fabulous day.	අද හරිම අපූරු දවසක්.
# Today, I saw a starling.	අද මම තරුනයෙක් දැක්කා.
# Tom accepted my present.	ටොම් මගේ තෑග්ග පිළිගත්තා.
# Tom always plays to win.	ටොම් හැම විටම දිනන්න සෙල්ලම් කරනවා.
# Tom and I live together.	ටොම් සහ මම එකට ජීවත් වෙනවා.
# Tom and I work together.	ටොම් සහ මම එකට වැඩ කරනවා.
# Tom and Mary had to run.	ටොම් සහ මේරිට දුවන්න වුණා.
# Tom appeared very tired.	ටොම්ට හොඳටම මහන්සි වෙලා වගේ.
# Tom applied for the job.	ටොම් රැකියාව සඳහා ඉල්ලුම් කළේය.
# Tom asked Mary for help.	ටොම් මේරිගෙන් උදව් ඉල්ලුවා.
# Tom asked for a receipt.	ටොම් රිසිට්පතක් ඉල්ලා සිටියේය.
# Tom asked me about Mary.	ටොම් මගෙන් මේරි ගැන ඇහුවා.
# Tom bandaged Mary's arm.	ටොම් මේරිගේ අත වෙළුම් පටියක් බැඳ ගත්තේය.
# Tom begged Mary to stay.	ටොම් මරියාට ඉන්න කියලා බැගෑපත්ව කිව්වා.
# Tom boiled the potatoes.	ටොම් අර්තාපල් තම්බා ගත්තේය.
# Tom bought a new camera.	ටොම් අලුත් කැමරාවක් ගත්තා.
# Tom broke both his legs.	ටොම් ඔහුගේ කකුල් දෙකම කැඩුවා.
# Tom brought Mary a gift.	ටොම් මේරිට තෑග්ගක් ගෙනාවා.
# Tom built his own house.	ටොම් ඔහුගේම නිවසක් ඉදි කළේය.
# Tom came here last week.	ටොම් ගිය සතියේ මෙහෙට ආවා.
# Tom came here yesterday.	ටොම් ඊයේ මෙහෙට ආවා.
# Tom came home very late.	ටොම් ගෙදර ආවේ ගොඩක් පරක්කු වෙලා.
# Tom came home yesterday.	ටොම් ඊයේ ගෙදර ආවා.
# Tom can't be that naive.	ටොම්ට ඒ බොළඳ වෙන්න බැහැ.
# Tom can't figure it out.	ටොම්ට ඒක තේරුම් ගන්න බෑ.
# Tom can't find his keys.	ටොම්ට ඔහුගේ යතුරු සොයාගත නොහැක.
# Tom can't have gone far.	ටොම්ට වැඩි දුරක් යන්න බෑ.
# Tom can't have gone far.	ටොම්ට වැඩි දුරක් යන්න බෑ.
# Tom can't hear anything.	ටොම්ට මොකුත් ඇහෙන්නේ නෑ.
# Tom can't run very fast.	ටොම්ට වැඩි වේගයකින් දුවන්න බෑ.
# Tom can't tell time yet.	ටොම්ට තාම වෙලාව කියන්න බෑ.
# Tom can't work tomorrow.	ටොම්ට හෙට වැඩ කරන්න බෑ.
# Tom certainly is clumsy.	ටොම් නිසැකවම අවුල් සහගතයි.
# Tom certainly is skinny.	ටොම් නිසැකවම කෙට්ටුයි.
# Tom chopped some onions.	ටොම් ළූණු ටිකක් කපලා.
# Tom clicked his fingers.	ටොම් ඔහුගේ ඇඟිලි ක්ලික් කළේය.
# Tom closed the car door.	ටොම් කාර් එකේ දොර වැහුවා.
# Tom closed the curtains.	ටොම් තිර රෙදි වසා දැමීය.
# Tom collected old coins.	ටොම් පැරණි කාසි එකතු කළේය.
# Tom couldn't believe it.	ටොම්ට ඒක විශ්වාස කරන්න බැරි වුණා.
# Tom couldn't believe it.	ටොම්ට ඒක විශ්වාස කරන්න බැරි වුණා.
# Tom couldn't say a word.	ටොම්ට වචනයක්වත් කියන්න බැරි වුණා.
# Tom crossed his fingers.	ටොම් ඔහුගේ ඇඟිලි හරස් කළේය.
# Tom deserves a vacation.	ටොම්ට නිවාඩුවක් ලැබිය යුතුයි.
# Tom deserves admiration.	ටොම්ට ප්‍රශංසාව ලැබිය යුතුය.
# Tom did a very good job.	ටොම් ඉතා හොඳ කාර්යයක් කළා.
# Tom did the right thing.	ටොම් කලේ හරි දේ.
# Tom did the unthinkable.	ටොම් සිතාගත නොහැකි දේ කළේය.
# Tom did worse this year.	ටොම් මේ වසරේ නරක අතට හැරුණි.
# Tom didn't believe Mary.	ටොම් මේරිව විශ්වාස කලේ නෑ.
# Tom didn't come, did he?	ටොම් ආවේ නෑ නේද?
# Tom didn't eat anything.	ටොම් මුකුත් කෑවේ නෑ.
# Tom didn't go to school.	ටොම් ඉස්කෝලේ ගියේ නෑ.
# Tom didn't mention that.	ටොම් ඒ ගැන සඳහන් කළේ නැහැ.
# Tom didn't say anything.	ටොම් මුකුත් කිව්වේ නෑ.
# Tom didn't seem to care.	ටොම් ගණන් ගත් බවක් පෙනෙන්නට නැත.
# Tom didn't want my help.	ටොම්ට මගේ උදව් ඕන වුණේ නැහැ.
# Tom didn't want to talk.	ටොම්ට කතා කරන්න ඕන වුණේ නැහැ.
# Tom didn't want to wait.	ටොම්ට බලා සිටීමට අවශ්‍ය නොවීය.
# Tom died Monday morning.	ටොම් සඳුදා උදෑසන මිය ගියේය.
# Tom died in an accident.	ටොම් හදිසි අනතුරකින් මිය ගියේය.
# Tom died when he was 97.	ටොම් මිය ගියේ ඔහුට වයස අවුරුදු 97 දී ය.
# Tom doesn't belong here.	ටොම් මෙතනට අයිති නෑ.
# Tom doesn't do anything.	ටොම් මොකුත් කරන්නේ නෑ.
# Tom doesn't have a clue.	ටොම්ට කිසිම හෝඩුවාවක් නැහැ.
# Tom doesn't have a visa.	ටොම්ට වීසා නැහැ.
# Tom doesn't have a wife.	ටොම්ට බිරිඳක් නැහැ.
# Tom doesn't know French.	ටොම් ප්රංශ භාෂාව දන්නේ නැහැ.
# Tom doesn't like coffee.	ටොම් කෝපි වලට කැමති නෑ.
# Tom doesn't like my dog.	ටොම් මගේ බල්ලන්ට කැමති නෑ.
# Tom doesn't like school.	ටොම් ඉස්කෝලෙ කැමති නෑ.
# Tom doesn't sound happy.	ටොම්ට සතුටක් දැනෙන්නේ නැහැ.
# Tom doesn't want to eat.	ටොම්ට කන්න ඕන නෑ.
# Tom dove into the water.	ටොම් පරෙවියා වතුරට.
# Tom dyed his hair black.	ටොම් ඔහුගේ කොණ්ඩය කළු කර ගත්තේය.
# Tom entered the kitchen.	ටොම් කුස්සියට ඇතුළු විය.
# Tom escaped from prison.	ටොම් හිරෙන් පැනලා ගියා.
# Tom eventually resigned.	ටොම් අවසානයේ ඉල්ලා අස්විය.
# Tom explained the rules.	ටොම් නීති පැහැදිලි කළේය.
# Tom felt a little dizzy.	ටොම්ට ටිකක් කරකැවිල්ල දැනුණා.
# Tom felt like a new man.	ටොම්ට දැනුනේ අලුත් මිනිහෙක් වගේ.
# Tom finally fell asleep.	ටොම්ට අන්තිමට නින්ද ගියා.
# Tom finally found a job.	ටොම් අවසානයේ රැකියාවක් සොයා ගත්තේය.
# Tom gave Mary a message.	ටොම් මේරිට පණිවිඩයක් දුන්නා.
# Tom gave Mary some food.	ටොම් මේරිට කෑම ටිකක් දුන්නා.
# Tom gave Mary some food.	ටොම් මේරිට කෑම ටිකක් දුන්නා.
# Tom gave his dog a bath.	ටොම් එයාගේ බල්ලව නාවන්න දුන්නා.
# Tom gave me a ride home.	ටොම් මට ගෙදර යන්න දුන්නා.
# Tom gave me some advice.	ටොම් මට උපදෙසක් දුන්නා.
# Tom gave me your number.	ටොම් මට ඔයාගේ අංකය දුන්නා.
# Tom gives me the creeps.	ටොම් මට රිංගනවා.
# Tom got angry with Mary.	ටොම් මේරි එක්ක තරහා ගියා.
# Tom got another message.	ටොම්ට තව පණිවිඩයක් ලැබුනා.
# Tom got dressed quickly.	ටොම් ඉක්මනින් ඇඳ පැළඳ සිටියේය.
# Tom got engaged to Mary.	ටොම් මේරි සමඟ විවාහ ගිවිස ගත්තා.
# Tom got into Mary's car.	ටොම් මේරිගේ කාර් එකට නැග්ගා.
# Tom got into Mary's car.	ටොම් මේරිගේ කාර් එකට නැග්ගා.
# Tom got on the elevator.	ටොම් සෝපානයට නැග්ගා.
# Tom got out of the taxi.	ටොම් ටැක්සියෙන් එළියට ආවා.
# Tom got out of the taxi.	ටොම් ටැක්සියෙන් එළියට ආවා.
# Tom had lunch with Mary.	ටොම් මේරි සමඟ දිවා ආහාරය ගත්තේය.
# Tom had no options left.	ටොම්ට විකල්ප කිසිවක් ඉතිරි නොවීය.
# Tom had nothing to hide.	ටොම්ට හංගන්න දෙයක් තිබුණේ නැහැ.
# Tom had nothing to read.	ටොම්ට කියවන්න දෙයක් තිබුනේ නෑ.
# Tom had to catch a taxi.	ටොම්ට කුලී රථයක් අල්ලා ගැනීමට සිදු විය.
# Tom handed Mary a knife.	ටොම් මේරිට පිහියක් දුන්නා.
# Tom has a Canadian wife.	ටොම්ට කැනේඩියානු බිරිඳක් සිටී.
# Tom has a decent salary.	ටොම්ට හොඳ වැටුපක් ඇත.
# Tom has a part-time job.	ටොම්ට අර්ධකාලීන රැකියාවක් තිබේ.
# Tom has a right to know.	ටොම්ට දැනගන්න අයිතියක් තියෙනවා.
# Tom has already seen it.	ටොම් දැනටමත් එය දැක ඇත.
# Tom has been texting me.	ටොම් මට කෙටි පණිවිඩයක් එව්වා.
# Tom has denied cheating.	ටොම් වංචාව ප්‍රතික්ෂේප කර ඇත.
# Tom has helped me a lot.	ටොම් මට ගොඩක් උදව් කළා.
# Tom has his own bedroom.	ටොම්ට ඔහුගේම නිදන කාමරයක් ඇත.
# Tom has never been sick.	ටොම් කවදාවත් අසනීප වෙලා නෑ.
# Tom has never been sick.	ටොම් කවදාවත් අසනීප වෙලා නෑ.
# Tom has no such problem.	ටොම්ට එහෙම ප්රශ්නයක් නෑ.
# Tom has nothing to hide.	ටොම්ට හංගන්න දෙයක් නෑ.
# Tom has nothing to lose.	ටොම්ට නැතිවෙන්න දෙයක් නෑ.
# Tom has three daughters.	ටොම්ට දියණියන් තිදෙනෙක් සිටී.
# Tom has three employees.	ටොම්ට සේවකයෝ තුන්දෙනෙක් ඉන්නවා.
# Tom has to get up early.	ටොම්ට වේලාසනින් නැගිටින්න වෙනවා.
# Tom has to get up early.	ටොම්ට වේලාසනින් නැගිටින්න වෙනවා.
# Tom has trouble reading.	ටොම්ට කියවීමේ අපහසුතා ඇති වේ.
# Tom has two girlfriends.	ටොම්ට පෙම්වතියන් දෙදෙනෙක් සිටී.
# Tom has wavy brown hair.	ටොම්ට රැලි සහිත දුඹුරු හිසකෙස් ඇත.
# Tom hasn't finished yet.	ටොම් තාම ඉවර නෑ.
# Tom hasn't unpacked yet.	ටොම් තවම ඉවත් කර නැත.
# Tom heard the door open.	ටොම්ට දොර ඇරලා ඇහුණා.
# Tom hid behind the door.	ටොම් දොර පිටුපස සැඟවී සිටියේය.
# Tom hid under the table.	ටොම් මේසය යට සැඟවී සිටියේය.
# Tom hugged Mary tightly.	ටොම් මේරිව තදින් වැළඳ ගත්තා.
# Tom is Mary's boyfriend.	ටොම් මේරිගේ පෙම්වතා.
# Tom is Mary's boyfriend.	ටොම් මේරිගේ පෙම්වතා.
# Tom is a French teacher.	ටොම් ප්රංශ ගුරුවරයෙකි.
# Tom is a brave skydiver.	ටොම් නිර්භීත ස්කයිඩයිවර් කෙනෙක්.
# Tom is a bright student.	ටොම් දීප්තිමත් ශිෂ්යයෙක්.
# Tom is a friend of mine.	ටොම් මගේ යාළුවෙක්.
# Tom is a good guitarist.	ටොම් හොඳ ගිටාර් වාදකයෙක්.
# Tom is a real gentleman.	ටොම් කියන්නේ නියම මහත්මයෙක්.
# Tom is a real gentleman.	ටොම් කියන්නේ නියම මහත්මයෙක්.
# Tom is a sincere person.	ටොම් අවංක පුද්ගලයෙක්.
# Tom is a sloppy painter.	ටොම් අලස චිත්‍ර ශිල්පියෙකි.
# Tom is a social drinker.	ටොම් සමාජශීලී මත්පැන් පානය කරන්නෙකු වේ.
# Tom is a talented actor.	ටොම් දක්ෂ නළුවෙක්.
# Tom is a tax consultant.	ටොම් බදු උපදේශකයෙකි.
# Tom is a very good cook.	ටොම් හොඳ කෝකියෙක්.
# Tom is a very smart boy.	ටොම් හරිම දක්ෂ කොල්ලෙක්.
# Tom is afraid of snakes.	ටොම් සර්පයන්ට බයයි.
# Tom is allergic to cats.	ටොම් බළලුන්ට ආසාත්මික වේ.
# Tom is allergic to dust.	ටොම් දූවිලි වලට ආසාත්මික වේ.
# Tom is already standing.	ටොම් දැනටමත් සිටගෙන සිටියි.
# Tom is already standing.	ටොම් දැනටමත් සිටගෙන සිටියි.
# Tom is always very nice.	ටොම් හැමවෙලේම හරිම ලස්සනයි.
# Tom is back with his ex.	ටොම් නැවතත් ඔහුගේ හිටපු අය සමඟ පැමිණ ඇත.
# Tom is biting his nails.	ටොම් ඔහුගේ නියපොතු සපා කෑවා.
# Tom is blind in one eye.	ටොම් එක ඇසක් අන්ධයි.
# Tom is braver than I am.	ටොම් මට වඩා නිර්භීතයි.
# Tom is buried in Boston.	ටොම් බොස්ටන්හි තැන්පත් කර ඇත.
# Tom is calm and patient.	ටොම් සන්සුන් හා ඉවසිලිවන්ත ය.
# Tom is clearly worn out.	ටොම් පැහැදිලිවම වෙහෙසට පත්ව සිටී.
# Tom is doing the dishes.	ටොම් පිඟන් කරනවා.
# Tom is driving too slow.	ටොම් බොහොම හෙමින් රිය පදවනවා.
# Tom is eating lunch now.	ටොම් දැන් දවල්ට කනවා.
# Tom is eating spaghetti.	ටොම් ස්පැගටි කනවා.
# Tom is extremely clumsy.	ටොම් හරිම අවුල් සහගතයි.
# Tom is feeding the cows.	ටොම් එළදෙනුන්ට කවනවා.
# Tom is feeling nauseous.	ටොම්ට ඔක්කාරය දැනෙනවා.
# Tom is fluent in French.	ටොම් ප්‍රංශ භාෂාව චතුර ලෙස කතා කරයි.
# Tom is getting restless.	ටොම්ට නොසන්සුන් වෙනවා.
# Tom is going to Harvard.	ටොම් හාවඩ් වලට යනවා.
# Tom is good at handball.	ටොම් හෑන්ඩ්බෝල් වලට දක්ෂයි.
# Tom is good at swimming.	ටොම් පීනන්න දක්ෂයි.
# Tom is good at swimming.	ටොම් පීනන්න දක්ෂයි.
# Tom is helping his wife.	ටොම් එයාගේ බිරිඳට උදව් කරනවා.
# Tom is hiding from Mary.	ටොම් මේරිගෙන් හැංගිලා ඉන්නවා.
# Tom is hiding from them.	ටොම් ඔවුන්ගෙන් සැඟවී සිටී.
# Tom is hiding something.	ටොම් යමක් හංගනවා.
# Tom is hiding somewhere.	ටොම් කොහේ හරි හැංගිලා ඉන්නවා.
# Tom is honest, isn't he?	ටොම් අවංකයි නේද?
# Tom is hyperventilating.	ටොම් අධි වාතාශ්‍රය ලබා දෙයි.
# Tom is in Mary's office.	ටොම් ඉන්නේ මේරිගේ ඔෆිස් එකේ.
# Tom is in enormous pain.	ටොම්ට ලොකු වේදනාවක් තියෙනවා.
# Tom is in love with you.	ටොම් ඔයාට ආදරෙයි.
# Tom is in the clubhouse.	ටොම් ඉන්නේ සමාජ ශාලාවේ.
# Tom is in the mess hall.	ටොම් ඉන්නේ අවුල් ශාලාවේ.
# Tom is in the warehouse.	ටොම් ඉන්නේ ගබඩාවේ.
# Tom is indebted to Mary.	ටොම් මේරිට ණයගැතියි.
# Tom is insanely jealous.	ටොම්ට ඉරිසියයි.
# Tom is kissing his wife.	ටොම් ඔහුගේ බිරිඳව සිප ගන්නවා.
# Tom is lazy and spoiled.	ටොම් කම්මැලි සහ නරක් වී ඇත.
# Tom is learning English.	ටොම් ඉංග්රීසි ඉගෙන ගන්නවා.
# Tom is learning English.	ටොම් ඉංග්රීසි ඉගෙන ගන්නවා.
# Tom is living his dream.	ටොම් ඔහුගේ සිහිනය ජීවත් කරයි.
# Tom is looking for Mary.	ටොම් මේරිව හොයනවා.
# Tom is looking for work.	ටොම් රස්සාවක් හොයනවා.
# Tom is making breakfast.	ටොම් උදේ කෑම හදනවා.
# Tom is manipulating you.	ටොම් ඔයාව හසුරුවනවා.
# Tom is missing a finger.	ටොම්ට ඇඟිල්ලක් නැතිවෙලා.
# Tom is my older brother.	ටොම් මගේ වැඩිමහල් සහෝදරයා.
# Tom is not a lazy child.	ටොම් කම්මැලි ළමයෙක් නෙවෙයි.
# Tom is picking his nose.	ටොම් ඔහුගේ නාසය තෝරා ගනී.
# Tom is preparing supper.	ටොම් රාත්‍රී ආහාරය සූදානම් කරමින් සිටී.
# Tom is proud of his son.	ටොම්ට පුතා ගැන ආඩම්බරයි.
# Tom is quite inflexible.	ටොම් තරමක් නම්‍යශීලී ය.
# Tom is quite photogenic.	ටොම් තරමක් ඡායාරූපජනක ය.
# Tom is rather eccentric.	ටොම් තරමක් විකේන්ද්රිකයි.
# Tom is riding a bicycle.	ටොම් බයිසිකලයක් පදිනවා.
# Tom is right, of course.	ටොම් හරි.
# Tom is right, of course.	ටොම් හරි.
# Tom is saying something.	ටොම් යමක් කියනවා.
# Tom is scared of ghosts.	ටොම් හොල්මන් වලට බයයි.
# Tom is shouting at Mary.	ටොම් මේරිට කෑ ගහනවා.
# Tom is smoking his pipe.	ටොම් ඔහුගේ නළය දුම් පානය කරයි.
# Tom is still a bachelor.	ටොම් තවමත් තනිකඩයෙකි.
# Tom is still a prisoner.	ටොම් තවමත් සිරකරුවෙකි.
# Tom is still just a boy.	ටොම් තාම කොල්ලෙක් විතරයි.
# Tom is still unemployed.	ටොම් තවමත් රැකියා විරහිතයි.
# Tom is still unemployed.	ටොම් තවමත් රැකියා විරහිතයි.
# Tom is sweating heavily.	ටොම්ට හොඳටම දහඩිය දානවා.
# Tom is taller than I am.	ටොම් මට වඩා උසයි.
# Tom is the real problem.	ටොම් තමයි ඇත්තම ප්රශ්නේ.
# Tom is the team manager.	ටොම් කණ්ඩායමේ කළමනාකරු වේ.
# Tom is thinking it over.	ටොම් ඒක හිතාගෙන ඉන්නවා.
# Tom is thinking it over.	ටොම් ඒක හිතාගෙන ඉන්නවා.
# Tom is thirty years old.	ටොම්ට වයස අවුරුදු තිහකි.
# Tom is tidying his room.	ටොම් ඔහුගේ කාමරය පිළිවෙලට තබයි.
# Tom is tidying his room.	ටොම් ඔහුගේ කාමරය පිළිවෙලට තබයි.
# Tom is too lazy to cook.	ටොම් උයන්න කම්මැලි වැඩියි.
# Tom is training his dog.	ටොම් එයාගේ බල්ලව පුහුණු කරනවා.
# Tom is upset about this.	ටොම් මේ ගැන කලබල වෙනවා.
# Tom is upset about this.	ටොම් මේ ගැන කලබල වෙනවා.
# Tom is very hardworking.	ටොම් හරිම වෙහෙස මහන්සි වෙලා වැඩ කරනවා.
# Tom is very incompetent.	ටොම් හරිම අදක්ෂයි.
# Tom is very intelligent.	ටොම් හරිම බුද්ධිමත්.
# Tom is very interesting.	ටොම් හරිම සිත්ගන්නා සුළුයි.
# Tom is watching a video.	ටොම් වීඩියෝවක් බලනවා.
# Tom is with his friends.	ටොම් ඉන්නේ ඔහුගේ යාළුවෝ එක්ක.
# Tom is with his parents.	ටොම් ඉන්නේ එයාගේ දෙමව්පියන් එක්ක.
# Tom is young and strong.	ටොම් තරුණ හා ශක්තිමත් ය.
# Tom isn't Mary's cousin.	ටොම් මේරිගේ ඥාති සහෝදරයෙක් නොවේ.
# Tom isn't a good person.	ටොම් හොඳ කෙනෙක් නෙවෙයි.
# Tom isn't a good singer.	ටොම් හොඳ ගායකයෙක් නෙමෙයි.
# Tom isn't a good worker.	ටොම් හොඳ සේවකයෙක් නෙවෙයි.
# Tom isn't a kid anymore.	ටොම් තව දුරටත් ළමයෙක් නෙවෙයි.
# Tom isn't being careful.	ටොම් පරිස්සම් වෙන්නේ නැහැ.
# Tom isn't in his office.	ටොම් එයාගේ ඔෆිස් එකේ නෑ.
# Tom isn't self employed.	ටොම් ස්වයං රැකියාවක් නොවේ.
# Tom isn't self employed.	ටොම් ස්වයං රැකියාවක් නොවේ.
# Tom isn't that far away.	ටොම් එච්චර දුර නෑ.
# Tom isn't very sociable.	ටොම් එතරම් සමාජශීලී නොවේ.
# Tom isn't wearing socks.	ටොම් මේස් දාගෙන නැහැ.
# Tom kept his mouth shut.	ටොම් කට වහගෙන හිටියා.
# Tom knew Mary was right.	ටොම් දැනගෙන හිටියා මේරි හරි කියලා.
# Tom knew Mary was right.	ටොම් දැනගෙන හිටියා මේරි හරි කියලා.
# Tom knew what he wanted.	ටොම් ඔහුට අවශ්‍ය දේ දැන සිටියේය.
# Tom knocked on the door.	ටොම් දොරට තට්ටු කළේය.
# Tom knocked on the door.	ටොම් දොරට තට්ටු කළේය.
# Tom knows Mary is wrong.	ටොම් දන්නවා මේරි වැරදියි කියලා.
# Tom knows Mary's father.	ටොම් දන්නවා මේරිගේ තාත්තා.
# Tom knows it's too late.	ටොම් දන්නවා පරක්කු වැඩියි කියලා.
# Tom knows what he likes.	ටොම් දන්නවා එයා කැමති දේ.
# Tom leaned on the table.	ටොම් මේසය මත හේත්තු විය.
# Tom leaped into the car.	ටොම් කාර් එකට පැන්නා.
# Tom left Mary a message.	ටොම් මේරිට පණිවිඩයක් දුන්නා.
# Tom left three days ago.	ටොම් යන්න ගියේ දවස් තුනකට කලින්.
# Tom likes action movies.	ටොම් ක්‍රියාදාම චිත්‍රපට වලට කැමතියි.
# Tom likes experimenting.	ටොම් අත්හදා බැලීමට කැමතියි.
# Tom likes the idea, too.	ටොම් අදහසටත් කැමතියි.
# Tom likes to drink beer.	ටොම් බියර් බොන්න ආසයි.
# Tom looked at the floor.	ටොම් බිම බැලුවා.
# Tom looks kind of tired.	ටොම්ට ටිකක් මහන්සියි වගේ.
# Tom looks like a banker.	ටොම් බැංකුකරුවෙක් වගේ.
# Tom looks like a banker.	ටොම් බැංකුකරුවෙක් වගේ.
# Tom looks like a banker.	ටොම් බැංකුකරුවෙක් වගේ.
# Tom loosened his collar.	ටොම් ඔහුගේ කරපටිය ලිහිල් කළේය.
# Tom lost a contact lens.	ටොම්ට අක්ෂි කාචයක් අහිමි විය.
# Tom loves sports events.	ටොම් ක්‍රීඩා ඉසව්වලට කැමතියි.
# Tom makes great burgers.	ටොම් නියම බර්ගර් හදනවා.
# Tom makes great burgers.	ටොම් නියම බර්ගර් හදනවා.
# Tom may spill the beans.	ටොම් බෝංචි වැගිරවිය හැක.
# Tom might become famous.	ටොම් ජනප්රිය වෙන්න පුළුවන්.
# Tom must be from Boston.	ටොම් බොස්ටන් වලින් විය යුතුය.
# Tom needs a good lawyer.	ටොම්ට හොඳ නීතිඥයෙක් ඕන.
# Tom needs a sharp knife.	ටොම්ට තියුණු පිහියක් ඕන.
# Tom never did that here.	ටොම් කවදාවත් මෙතන එහෙම කළේ නැහැ.
# Tom never makes his bed.	ටොම් කවදාවත් එයාගේ ඇඳ හදන්නේ නැහැ.
# Tom never makes his bed.	ටොම් කවදාවත් එයාගේ ඇඳ හදන්නේ නැහැ.
# Tom never said anything.	ටොම් කවදාවත් මුකුත් කිව්වේ නැහැ.
# Tom never said one word.	ටොම් කවදාවත් එක වචනයක්වත් කිව්වේ නැහැ.
# Tom never saw her again.	ටොම් නැවත කිසි දිනෙක ඇයව දැක නැත.
# Tom never saw her again.	ටොම් නැවත කිසි දිනෙක ඇයව දැක නැත.
# Tom never talks to Mary.	ටොම් කවදාවත් මේරි එක්ක කතා කරන්නේ නැහැ.
# Tom nodded in agreement.	ටොම් එකඟතාවයෙන් හිස සැලුවේය.
# Tom now lives in Boston.	ටොම් දැන් ජීවත් වන්නේ බොස්ටන්හි ය.
# Tom offered Mary a beer.	ටොම් මේරිට බියර් එකක් දුන්නා.
# Tom often has headaches.	ටොම්ට බොහෝ විට හිසරදය ඇති වේ.
# Tom opened his suitcase.	ටොම් ඔහුගේ ගමන් මල්ල විවෘත කළේය.
# Tom opened the car door.	ටොම් කාර් එකේ දොර ඇරියා.
# Tom opened the curtains.	ටොම් තිර රෙදි විවෘත කළේය.
# Tom opened the envelope.	ටොම් ලියුම් කවරය විවෘත කළේය.
# Tom paid by credit card.	ටොම් ක්‍රෙඩිට් කාඩ් එකෙන් ගෙවනවා.
# Tom paid for everything.	ටොම් හැමදේටම ගෙව්වා.
# Tom paid for the ticket.	ටොම් ටිකට් එකට ගෙව්වා.
# Tom peeled the potatoes.	ටොම් අර්තාපල් ලෙලි ගැහුවා.
# Tom picked up the phone.	ටොම් ෆෝන් එක ගත්තා.
# Tom pledged his support.	ටොම් ඔහුගේ සහයෝගය පොරොන්දු විය.
# Tom plucked the chicken.	ටොම් කුකුල් මස් උදුරා ගත්තා.
# Tom pretended to be ill.	ටොම් අසනීපයෙන් සිටින බව මවා පෑවේය.
# Tom put on his overcoat.	ටොම් ඔහුගේ කබාය පැළඳ සිටියේය.
# Tom put on his swimsuit.	ටොම් ඔහුගේ පිහිනුම් ඇඳුම ඇඳ සිටියේය.
# Tom put up his umbrella.	ටොම් ඔහුගේ කුඩය තැබුවේය.
# Tom ran down the stairs.	ටොම් පඩිපෙළෙන් බැස ගියේය.
# Tom ran out of the room.	ටොම් කාමරයෙන් පැනලා ගියා.
# Tom read a poem to Mary.	ටොම් මේරිට කවියක් කියෙව්වා.
# Tom removed his glasses.	ටොම් ඔහුගේ කණ්නාඩි ඉවත් කළේය.
# Tom respects Mary a lot.	ටොම් මේරිට ගොඩක් ගරු කරනවා.
# Tom respects his elders.	ටොම් ඔහුගේ වැඩිහිටියන්ට ගරු කරයි.
# Tom responded instantly.	ටොම් ක්ෂණිකව ප්රතිචාර දැක්වීය.
# Tom rested for a moment.	ටොම් මොහොතකට විවේක ගත්තේය.
# Tom revealed his secret.	ටොම් ඔහුගේ රහස හෙළි කළේය.
# Tom revealed the secret.	ටොම් රහස හෙළි කළේය.
# Tom rinsed off the soap.	ටොම් සබන් සෝදා ගත්තේය.
# Tom runs faster than me.	ටොම් මට වඩා වේගයෙන් දුවනවා.
# Tom said he didn't know.	ටොම් කිව්වා එයා දන්නේ නෑ කියලා.
# Tom said he saw nothing.	ටොම් කිව්වා එයා මුකුත් දැක්කේ නෑ කියලා.
# Tom said he was thirsty.	ටොම් කිව්වා පිපාසයෙන් කියලා.
# Tom said he's no expert.	ටොම් කිව්වා එයා විශේෂඥයෙක් නෙවෙයි කියලා.
# Tom said he's no expert.	ටොම් කිව්වා එයා විශේෂඥයෙක් නෙවෙයි කියලා.
# Tom sat down on the bed.	ටොම් ඇඳ උඩ වාඩි වුණා.
# Tom sat on a park bench.	ටොම් උද්‍යාන බංකුවක වාඩි විය.
# Tom says he can't sleep.	ටොම් කියනවා එයාට නිදාගන්න බෑ කියලා.
# Tom says he killed Mary.	ටොම් කියනවා එයා මේරිව මැරුවා කියලා.
# Tom says he's not happy.	ටොම් කියනවා එයා සතුටු නෑ කියලා.
# Tom says this is absurd.	ටොම් කියනවා මේක විකාරයක් කියලා.
# Tom says this is normal.	ටොම් කියනවා මේක සාමාන්යයි කියලා.
# Tom seconded the motion.	ටොම් යෝජනාව ස්ථිර කළේය.
# Tom seemed unsuccessful.	ටොම් අසාර්ථක වූ බවක් පෙනෙන්නට තිබුණි.
# Tom seems like an idiot.	ටොම් මෝඩයෙක් වගේ.
# Tom seems like an idiot.	ටොම් මෝඩයෙක් වගේ.
# Tom seems to be in love.	ටොම් ආදරයෙන් බැඳී සිටින බව පෙනේ.
# Tom seems to be nervous.	ටොම් කලබල වී ඇති බව පෙනේ.
# Tom seems to be nervous.	ටොම් කලබල වී ඇති බව පෙනේ.
# Tom seldom eats at home.	ටොම් ගෙදර කන්නේ කලාතුරකිනි.
# Tom seldom eats seafood.	ටොම් මුහුදු ආහාර අනුභව කරන්නේ කලාතුරකිනි.
# Tom sent Mary a message.	ටොම් මේරිට පණිවිඩයක් එව්වා.
# Tom should be here soon.	ටොම් ඉක්මනට මෙහෙට එන්න ඕන.
# Tom should be home soon.	ටොම් ඉක්මනට ගෙදර යාවි.
# Tom should be in school.	ටොම් ඉස්කෝලේ යන්න ඕන.
# Tom should've told Mary.	ටොම් මේරිට කියන්න තිබුණා.
# Tom showed Mary the way.	ටොම් මේරිට පාර පෙන්නුවා.
# Tom showered and shaved.	ටොම් වැස්ස සහ රැවුල කපා.
# Tom signed the contract.	ටොම් ගිවිසුම අත්සන් කළේය.
# Tom sleeps all the time.	ටොම් නිතරම නිදාගන්නවා.
# Tom slept in his office.	ටොම් නිදාගත්තේ ඔහුගේ කාර්යාලයේය.
# Tom sliced the tomatoes.	ටොම් තක්කාලි පෙති කැපුවා.
# Tom snapped his fingers.	ටොම් ඔහුගේ ඇඟිලි ගැසුවේය.
# Tom speaks very quickly.	ටොම් බොහොම ඉක්මනට කතා කරනවා.
# Tom spit out the poison.	ටොම් වස කෙළ ගැසුවා.
# Tom squeezed the sponge.	ටොම් ස්පොන්ජිය මිරිකා.
# Tom still has some time.	ටොම්ට තව කාලයක් තියෙනවා.
# Tom still loves his job.	ටොම් තවමත් ඔහුගේ රැකියාවට කැමතියි.
# Tom stinks at chemistry.	ටොම් රසායන විද්‍යාවේදී ගඳ ගසයි.
# Tom stood close to Mary.	ටොම් මරියාට සමීප විය.
# Tom talked about Boston.	ටොම් බොස්ටන් ගැන කතා කළා.
# Tom talked in his sleep.	ටොම් නින්දේදී කතා කළේය.
# Tom tends to exaggerate.	ටොම් අතිශයෝක්තියට නැංවීමට නැඹුරු වේ.
# Tom thinks he's in love.	ටොම් හිතන්නේ එයා ආදරය කරනවා කියලා.
# Tom thinks that'll work.	ටොම් හිතනවා ඒක වැඩ කරයි කියලා.
# Tom thinks that's crazy.	ටොම් හිතන්නේ ඒක පිස්සුවක් කියලා.
# Tom thinks that's crazy.	ටොම් හිතන්නේ ඒක පිස්සුවක් කියලා.
# Tom thinks there's hope.	ටොම් හිතනවා බලාපොරොත්තුවක් තියෙනවා කියලා.
# Tom thinks you're lying.	ටොම් හිතන්නෙ ඔයා බොරු කියනවා කියල.
# Tom thought I knew Mary.	ටොම් හිතුවේ මම මේරිව දන්නවා කියලා.
# Tom threw Mary the ball.	ටොම් මේරිට පන්දුව විසි කළේය.
# Tom told Mary not to go.	ටොම් මේරිට කිව්වා යන්න එපා කියලා.
# Tom told Mary the truth.	ටොම් මේරිට ඇත්ත කිව්වා.
# Tom told us all a story.	ටොම් අපි හැමෝටම කතාවක් කිව්වා.
# Tom took Mary back home.	ටොම් මේරිව ආපහු ගෙදර ගෙනියනවා.
# Tom took Mary to dinner.	ටොම් මේරිව රාත්‍රී භෝජන සංග්‍රහයට රැගෙන ගියා.
# Tom took off his jacket.	ටොම් ඔහුගේ ජැකට් එක ගලවා දැමුවේය.
# Tom took some food home.	ටොම් ගෙදර කෑම ටිකක් ගෙනියනවා.
# Tom tried to be neutral.	ටොම් මධ්‍යස්ථ වීමට උත්සාහ කළේය.
# Tom tried to reach Mary.	ටොම් මරියා වෙත ළඟා වීමට උත්සාහ කළේය.
# Tom turned on the light.	ටොම් ආලෝකය දැල්වීය.
# Tom turned on the radio.	ටොම් රේඩියෝව ක්‍රියාත්මක කළේය.
# Tom underestimated Mary.	ටොම් මේරිව අවතක්සේරු කළා.
# Tom unholstered his gun.	ටොම් ඔහුගේ තුවක්කුව ගලවා ගත්තේය.
# Tom unlocked the drawer.	ටොම් ලාච්චුව අගුළු හැරියේය.
# Tom unzipped his jacket.	ටොම් ඔහුගේ ජැකට් එක ගලවා දැමුවේය.
# Tom used to hate Boston.	ටොම් බොස්ටන්ට වෛර කළා.
# Tom used to play guitar.	ටොම් ගිටාර් වාදනය කළා.
# Tom used to write songs.	ටොම් ගීත ලිව්වා.
# Tom volunteered to help.	ටොම් උදව් කිරීමට ස්වේච්ඡාවෙන් ඉදිරිපත් විය.
# Tom waited breathlessly.	ටොම් හුස්ම නොගෙන බලා සිටියේය.
# Tom walked out on stage.	ටොම් වේදිකාවෙන් පිටව ගියේය.
# Tom walked over to Mary.	ටොම් මරියා වෙත ගියේය.
# Tom walked over to Mary.	ටොම් මරියා වෙත ගියේය.
# Tom wanted to help Mary.	ටොම්ට මරියාට උදව් කරන්න ඕන වුණා.
# Tom wanted to thank you.	ටොම්ට ඕන වුනේ ඔයාට ස්තුති කරන්න.
# Tom wanted us to see it.	ටොම්ට ඕන වුනේ අපි ඒක බලන්න.
# Tom wanted us to see it.	ටොම්ට ඕන වුනේ අපි ඒක බලන්න.
# Tom wants to be a pilot.	ටොම්ට ගුවන් නියමුවෙක් වෙන්න ඕන.
# Tom wants to be admired.	ටොම්ට ඕන අගය කරන්න.
# Tom wants to go hunting.	ටොම්ට ඕන දඩයම් කරන්න.
# Tom wants to marry Mary.	ටොම්ට මේරිව විවාහ කරගන්න ඕන.
# Tom was John's cellmate.	ටොම් ජෝන්ගේ සිරමැදිරිය විය.
# Tom was John's roommate.	ටොම් ජෝන්ගේ නේවාසික මිතුරා විය.
# Tom was angry with Mary.	ටොම් මේරි එක්ක තරහින් හිටියා.
# Tom was arrested Monday.	ටොම් අත්අඩංගුවට ගනු ලැබුවේ සඳුදා ය.
# Tom was bitten by a bat.	ටොම්ට පිත්තෙන් දෂ්ට කළා.
# Tom was bitten by a bat.	ටොම්ට පිත්තෙන් දෂ්ට කළා.
# Tom was caught in a lie.	ටොම් බොරුවකට අහුවුණා.
# Tom was caught in a lie.	ටොම් බොරුවකට අහුවුණා.
# Tom was caught in a lie.	ටොම් බොරුවකට අහුවුණා.
# Tom was deep in thought.	ටොම් ගැඹුරින් කල්පනා කළේය.
# Tom was deep in thought.	ටොම් ගැඹුරින් කල්පනා කළේය.
# Tom was deep in thought.	ටොම් ගැඹුරින් කල්පනා කළේය.
# Tom was elected in 2010.	ටොම් 2010 දී තේරී පත් විය.
# Tom was fired on Monday.	ටොම් සඳුදා සේවයෙන් පහ කරන ලදී.
# Tom was in a wheelchair.	ටොම් හිටියේ රෝද පුටුවක.
# Tom was in the audience.	ටොම් ප්‍රේක්ෂකාගාරයේ සිටියේය.
# Tom was late for dinner.	ටොම් රාත්‍රී ආහාරය සඳහා ප්‍රමාද විය.
# Tom was more than ready.	ටොම් ඊට වඩා සූදානම් විය.
# Tom was probably joking.	ටොම් විහිළුවක් කරල ඇති.
# Tom was probably joking.	ටොම් විහිළුවක් කරල ඇති.
# Tom was reluctant to go.	ටොම් යන්න මැලි වුණා.
# Tom was scared to death.	ටොම් මරණයට බිය විය.
# Tom was very frustrated.	ටොම් ගොඩක් කලකිරුණා.
# Tom was waiting for you.	ටොම් ඔයා එනකම් බලන් හිටියා.
# Tom wasn't able to swim.	ටොම්ට පීනන්න බැරි වුණා.
# Tom watched attentively.	ටොම් අවධානයෙන් බැලුවා.
# Tom watered the flowers.	ටොම් මල් වලට වතුර දැම්මා.
# Tom wears silk neckties.	ටොම් සිල්ක් ගෙල පැළඳ සිටී.
# Tom went to the library.	ටොම් පුස්තකාලයට ගියා.
# Tom will be bored stiff.	ටොම්ට දැඩි කම්මැලියි.
# Tom will be bored stiff.	ටොම්ට දැඩි කම්මැලියි.
# Tom will have no choice.	ටොම්ට වෙන විකල්පයක් නෑ.
# Tom will quit on Monday.	ටොම් සඳුදා ඉවත් වෙයි.
# Tom will remain at home.	ටොම් ගෙදර ඉන්නම්.
# Tom will tell the truth.	ටොම් ඇත්ත කියයි.
# Tom won the competition.	ටොම් තරඟය ජය ගත්තේය.
# Tom won't be successful.	ටොම් සාර්ථක නොවනු ඇත.
# Tom wore a white jacket.	ටොම් සුදු ජැකට් එකක් ඇඳ සිටියේය.
# Tom wore a white jacket.	ටොම් සුදු ජැකට් එකක් ඇඳ සිටියේය.
# Tom wore a white jacket.	ටොම් සුදු ජැකට් එකක් ඇඳ සිටියේය.
# Tom worked all his life.	ටොම් ඔහුගේ මුළු ජීවිත කාලයම වැඩ කළේය.
# Tom works in archeology.	ටොම් පුරාවිද්‍යාවේ වැඩ කරනවා.
# Tom works on an oil rig.	ටොම් වැඩ කරන්නේ තෙල් වළක.
# Tom would never do that.	ටොම් කවදාවත් එහෙම කරන්නේ නැහැ.
# Tom wrote Mary a letter.	ටොම් මේරිට ලිපියක් ලිව්වා.
# Tom wrung out the towel.	ටොම් තුවායෙන් එළියට විසි කළා.
# Tom! What are you doing?	ටොම්! ඔයා මොනවද කරන්නේ?
# Tom's French is perfect.	ටොම්ගේ ප්රංශ පරිපූර්ණයි.
# Tom's birthday is today.	ටොම්ගෙ උපන් දිනය අද.
# Tom's car was impounded.	ටොම්ගේ මෝටර් රථය අත්අඩංගුවට ගෙන ඇත.
# Tom's car was impounded.	ටොම්ගේ මෝටර් රථය අත්අඩංගුවට ගෙන ඇත.
# Tom's days are numbered.	ටොම්ගේ දින ගණන් කර ඇත.
# Tom's dog attacked Mary.	ටොම්ගේ බල්ලා මේරිට පහර දුන්නා.
# Tom's father is in jail.	ටොම්ගෙ තාත්තා හිරේ.
# Tom's house burned down.	ටොම්ගේ නිවස ගිනිබත් විය.
# Tom's house is for sale.	ටොම්ගේ නිවස විකිණීමට ඇත.
# Tom's house was on fire.	ටොම්ගේ නිවස ගිනිගෙන ඇත.
# Tom's in a slump lately.	ටොම් මෑතකදී පසුබෑමකට ලක් විය.
# Tom's not in the office.	ටොම් ඔෆිස් එකේ නෑ.
# Tom's not very handsome.	ටොම් එච්චර කඩවසම් නෑ.
# Tom's room wasn't clean.	ටොම්ගේ කාමරය පිරිසිදු නැත.
# Tom's shirt is wrinkled.	ටොම්ගේ කමිසය රැලි වැටී ඇත.
# Tom's strategy paid off.	ටොම්ගේ උපාය සාර්ථක විය.
# Tom's wife is a teacher.	ටොම්ගේ බිරිඳ ගුරුවරියකි.
# Tom, get us out of here!	ටොම්, අපිව මෙතනින් එලියට ගන්න!
# Tomorrow is another day.	හෙට තවත් දවසක්.
# Toss your gun over here.	තුවක්කුව මෙතනින් විසි කරන්න.
# Try not to move so much.	එතරම් චලනය නොවී සිටීමට උත්සාහ කරන්න.
# Try solving the problem.	ගැටළුව විසඳීමට උත්සාහ කරන්න.
# Try solving the problem.	ගැටළුව විසඳීමට උත්සාහ කරන්න.
# Try to control yourself.	ඔබම පාලනය කරගන්න උත්සාහ කරන්න.
# Try to keep from crying.	අඬන්න උත්සාහ කරන්න.
# Turn left at the corner.	කෙළවරේ වමට හැරෙන්න.
# Turn on your headlights.	ඔබේ හෙඩ් ලයිට් දල්වන්න.
# Turn on your headlights.	ඔබේ හෙඩ් ලයිට් දල්වන්න.
# Turn on your headlights.	ඔබේ හෙඩ් ලයිට් දල්වන්න.
# Turn the flame down low.	දැල්ල පහලට හරවන්න.
# Two plus two makes four.	දෙකක් ප්ලස් දෙකක් හතරක් කරයි.
# Two plus two makes four.	දෙකක් ප්ලස් දෙකක් හතරක් කරයි.
# Two plus two makes four.	දෙකක් ප්ලස් දෙකක් හතරක් කරයි.
# Use the manual override.	අත්පොත අභිබවා යන්න භාවිතා කරන්න.
# Very few people know it.	ඒක දන්නේ බොහොම ටික දෙනයි.
# Wanna crash at my place?	මගේ තැන කඩා වැටෙන්න ඕනද?
# Was Mary wearing a cape?	මේරි කේප් එකක් ඇඳගෙන හිටියද?
# Was that you in the car?	ඒ ඔයා කාර් එකේ හිටියද?
# Was that you in the car?	ඒ ඔයා කාර් එකේ හිටියද?
# We all stood up at once.	අපි හැමෝම එකපාරට නැගිට්ටා.
# We all want to be happy.	අපි හැමෝටම ඕන සතුටින් ඉන්න.
# We appreciate your help.	අපි ඔබගේ උදව් අගය කරමු.
# We are all in agreement.	අපි හැමෝම එකඟයි.
# We are expecting a baby.	අපි දරුවෙක් බලාපොරොත්තුවෙන් ඉන්නවා.
# We are glad to help you.	ඔබට උදව් කිරීමට ලැබීම ගැන අපි සතුටු වෙමු.
# We are having a meeting.	අපි රැස්වීමක් තියෙනවා.
# We are having breakfast.	අපි උදේ කෑම ගන්නවා.
# We bought new furniture.	අපි අලුත් ගෘහ භාණ්ඩ මිලදී ගත්තා.
# We can open the windows.	අපිට ජනෙල් අරින්න පුළුවන්.
# We can still break even.	අපිට තාමත් කඩන්න පුළුවන්.
# We can still break even.	අපිට තාමත් කඩන්න පුළුවන්.
# We can't guarantee that.	අපිට ඒක සහතික කරන්න බෑ.
# We can't live like this.	අපිට මෙහෙම ජීවත් වෙන්න බෑ.
# We can't wait two weeks.	අපිට සති දෙකක් බලා ඉන්න බෑ.
# We celebrated all night.	අපි මුළු රෑම සමරනවා.
# We didn't find a weapon.	අපිට ආයුධ හම්බුනේ නෑ.
# We didn't have much fun.	අපි වැඩිය විනෝද වුණේ නැහැ.
# We didn't think of that.	අපි ඒ ගැන හිතුවේ නැහැ.
# We dined at our uncle's.	අපි මාමාගේ කෑම කෑවා.
# We do this every Monday.	අපි හැම සඳුදා ම මේ දේ කරනවා.
# We don't have any sugar.	අපිට සීනි නැහැ.
# We don't have much time.	අපිට වැඩි වෙලාවක් නැහැ.
# We don't have that long.	අපිට එච්චර වෙලාවක් නෑ.
# We don't have the money.	අපිට සල්ලි නෑ.
# We don't live in Boston.	අපි ජීවත් වෙන්නේ බොස්ටන් වල නෙවෙයි.
# We expected you at 2:30.	අපි ඔයාව 2.30ට බලාපොරොත්තු වුනා.
# We felt the house shake.	නිවස සෙලවෙන බවක් අපට දැනුනි.
# We fought a hard battle.	අපි දරුණු සටනක් දුන්නා.
# We gave him up for dead.	අපි එයාව මැරුණට අතෑරලා දැම්මා.
# We got lost in the snow.	අපි හිම වල අතරමං වෙලා.
# We had a secret meeting.	රහසිගත හමුවක් තිබුණා.
# We had a secret meeting.	රහසිගත හමුවක් තිබුණා.
# We had a snowball fight.	අපි හිමබෝල සටනක් කළා.
# We had no help from Tom.	අපිට ටොම්ගෙන් උදව්වක් ලැබුනේ නෑ.
# We had no help from Tom.	අපිට ටොම්ගෙන් උදව්වක් ලැබුනේ නෑ.
# We had to react quickly.	අපිට ඉක්මනට ප්රතිචාර දක්වන්න වුණා.
# We have a cat and a dog.	අපිට බල්ලෙක් සහ පූසෙක් ඉන්නවා.
# We have a test tomorrow.	හෙට පරීක්ෂණයක් තියෙනවා.
# We have dinner at seven.	අපි හතට රෑ කෑම ගන්නවා.
# We have enough food now.	දැන් අපිට ඕන තරම් කෑම තියෙනවා.
# We have lunch at midday.	අපි දවල්ට දවල්ට දවල්ට දවල්ට කෑම ගන්නවා.
# We have no alternatives.	අපිට විකල්ප නැහැ.
# We have no other choice.	අපිට වෙන විකල්පයක් නෑ.
# We have no other option.	අපට වෙන විකල්පයක් නැහැ.
# We have no school today.	අද අපිට පාසලක් නැහැ.
# We have nothing to hide.	අපිට හංගන්න දෙයක් නෑ.
# We have nothing to lose.	අපිට නැතිවෙන්න දෙයක් නෑ.
# We have nowhere to hide.	අපිට හැංගෙන්න තැනක් නැහැ.
# We have only one chance.	අපිට තියෙන්නේ එක අවස්ථාවක් විතරයි.
# We have only three days.	අපිට තියෙන්නේ දවස් තුනක් විතරයි.
# We have some great news!	අපිට හොඳ ආරංචියක් ලැබුණා!
# We have to keep working.	අපි දිගටම වැඩ කරන්න ඕන.
# We have to stay healthy.	අපි නිරෝගීව සිටිය යුතුයි.
# We have to wait for him.	අපි ඔහු එනකම් බලාගෙන ඉන්න ඕන.
# We haven't met for ages.	අපි අවුරුදු ගානකින් හම්බවෙලා නෑ.
# We heard somebody shout.	කවුරුහරි කෑගහනවා ඇහුණා.
# We heard the door close.	දොර වහගෙන ඇහුණා.
# We improved the quality.	අපි ගුණාත්මකභාවය වැඩි දියුණු කළා.
# We just needed to relax.	අපට අවශ්ය වුණේ විවේකීව ඉන්න විතරයි.
# We live near the border.	අපි ජීවත් වෙන්නේ දේශ සීමාව ආසන්නයේ.
# We looked at each other.	අපි එකිනෙකා දිහා බැලුවා.
# We may not win tomorrow.	හෙට දිනන්නත් බෑ.
# We must remain vigilant.	අපි සුපරීක්ෂාකාරීව සිටිය යුතුයි.
# We need to raise prices.	අපි මිල වැඩි කළ යුතුයි.
# We need to raise prices.	අපි මිල වැඩි කළ යුතුයි.
# We needn't have hurried.	අපි ඉක්මන් කරන්න ඕන නෑ.
# We never got the chance.	අපිට කවදාවත් අවස්ථාව ලැබිලා නෑ.
# We never got the chance.	අපිට කවදාවත් අවස්ථාව ලැබිලා නෑ.
# We never stood a chance.	අපි කවදාවත් අවස්ථාවක් ලබා ගත්තේ නැහැ.
# We never work on Sunday.	අපි කවදාවත් ඉරිදා වැඩ කරන්නේ නැහැ.
# We put sugar in our tea.	අපි තේ වලට සීනි දැම්මා.
# We rented the apartment.	අපි මේ මහල් නිවාසය කුලියට ගත්තා.
# We reported him missing.	ඔහු අතුරුදහන් වූ බව අපි වාර්තා කළෙමු.
# We saw a light far away.	අපි දැක්කේ ඈත ආලෝකයක්.
# We still have more time.	අපිට තව කාලය තියෙනවා.
# We talked quite frankly.	අපි අවංකවම කතා කළා.
# We thanked Tom for that.	අපි ඒ වෙනුවෙන් ටොම්ට ස්තුති කළා.
# We waited there quietly.	අපි නිහඬව එතන බලාගෙන හිටියා.
# We walked for two hours.	අපි පැය දෙකක් ඇවිද්දා.
# We want to see the king.	අපිට රජතුමාව බලන්න ඕන.
# We wasted a lot of time.	අපි සෑහෙන වෙලාවක් නාස්ති කළා.
# We were always together.	අපි හැමවෙලේම එකට හිටියා.
# We were looking for you.	අපි ඔයාව හෙව්වා.
# We were pretty thorough.	අපි බොහොම හොඳින් හිටියා.
# We were the only guests.	අපි විතරයි අමුත්තෝ.
# We were truly surprised.	ඇත්තටම අපි පුදුම වුණා.
# We weren't tired at all.	අපිට කොහෙත්ම මහන්සි නෑ.
# We will be back tonight.	අපි අද රෑට එන්නම්.
# We will visit them soon.	අපි ඉක්මනටම එයාලව බලන්න යනවා.
# We won the bronze medal.	අපි ලෝකඩ පදක්කම දිනුවා.
# We'd better go home now.	අපි දැන් ගෙදර යන එක හොඳයි.
# We'll always be friends.	අපි හැමදාමත් යාළුවො වෙමු.
# We'll be late for class.	අපි පන්තියට පරක්කු වෙනවා.
# We'll have a great time.	අපිට හොඳ කාලයක් ලැබෙයි.
# We'll have to come back.	අපිට ආපහු එන්න වෙනවා.
# We'll leave without him.	අපි එයා නැතුව යනවා.
# We'll see Tom next week.	අපි ටොම්ව ලබන සතියේ හමුවෙමු.
# We'll see Tom next week.	අපි ටොම්ව ලබන සතියේ හමුවෙමු.
# We're all tired of this.	අපි හැමෝටම මේක එපා වෙලා.
# We're feeling confident.	අපිට විශ්වාසයි.
# We're going home by car.	අපි ගෙදර යන්නේ කාර් එකෙන්.
# We're having lunch here.	අපි මෙතන දවල් කෑම ගන්නවා.
# We're here to play golf.	අපි ආවේ ගොල්ෆ් ක්රීඩා කරන්න.
# We're looking into that.	අපි ඒ ගැන හොයනවා.
# We're lucky to be alive.	අපි වාසනාවන්තයි ජිවත් වෙන්න.
# We're not gonna make it.	අපි ඒක හදන්නේ නැහැ.
# We're not the champions.	අපි ශූරයෝ නෙවෙයි.
# We're not young anymore.	අපි තවදුරටත් තරුණ නැහැ.
# We're proud of our team.	අපේ කණ්ඩායම ගැන ආඩම්බරයි.
# We're smarter than that.	අපි ඊට වඩා බුද්ධිමත්.
# We're very proud of Tom.	අපි ටොම් ගැන ආඩම්බරයි.
# We're very proud of you.	අපි ඔබ ගැන ආඩම්බරයි.
# We're very proud of you.	අපි ඔබ ගැන ආඩම්බරයි.
# We've all been laid off.	අපි හැමෝම දොට්ට දැම්මා.
# We've been there before.	අපි මීට කලින් එතන හිටියා.
# We've been unsuccessful.	අපි අසාර්ථකයි.
# We've got a big problem.	අපිට ලොකු ප්රශ්නයක් තියෙනවා.
# We've had a lot of rain.	අපිට ගොඩක් වැස්ස තියෙනවා.
# Were you born in a barn?	ඔයා ඉපදුනේ අාර් ඒන් එකකද?
# Were you busy last week?	ගිය සතියේ කාර්යබහුල වුණාද?
# Were you busy yesterday?	ඊයේ කාර්යබහුලද?
# Were you here last week?	ඔයා ගිය සතියේ මෙහෙ ආවද?
# Were you out last night?	ඊයේ රෑ ඔයා එළියට ගියාද?
# What I do is my problem.	මම කරන දේ තමයි මගේ ප්රශ්නය.
# What Tom said was a lie.	ටොම් කියපු දේ බොරුවක්.
# What a beautiful flower!	ලස්සන මලක්!
# What a beautiful garden!	ලස්සන වත්තක්!
# What a beautiful garden!	ලස්සන වත්තක්!
# What a beautiful garden!	ලස්සන වත්තක්!
# What a beautiful sunset!	හරිම ලස්සන හිරු බැස යෑමක්!
# What a beautiful sunset.	හරිම ලස්සන හිරු බැස යෑමක්.
# What a nice looking car!	ලස්සන පෙනුමැති වාහනයක්!
# What a wonderful family.	මොනතරම් අපූරු පවුලක්ද.
# What are the conditions?	කොන්දේසි මොනවාද?
# What are we waiting for?	අපි බලා සිටින්නේ කුමක් සඳහාද?
# What are you crying for?	මොනවටද ඔයා අඬන්නෙ?
# What are you doing here?	ඔයා මොනවද මෙතන කරන්නේ?
# What are you doing here?	ඔයා මොනවද මෙතන කරන්නේ?
# What are you driving at?	ඔයා පදවන්නේ මොනවටද?
# What are you looking at?	මොනවද ඔයා බලන්නේ?
# What are you sitting on?	මොනවද ඔයා වාඩිවෙලා ඉන්නේ?
# What are you staring at?	ඔයා බලන්නේ මොනවද?
# What are you staring at?	ඔයා බලන්නේ මොනවද?
# What are you suggesting?	මොනවද ඔබ යෝජනා කරන්නේ?
# What are you suggesting?	මොනවද ඔබ යෝජනා කරන්නේ?
# What can you do for Tom?	ටොම් වෙනුවෙන් මොනවද කරන්න පුලුවන්?
# What color is Tom's car?	ටොම්ගෙ කාර් එක මොන පාටද?
# What color is Tom's dog?	ටොම්ගේ බල්ලාගේ වර්ණය කුමක්ද?
# What color is your hair?	කොණ්ඩේ මොන පාටද?
# What did I leave behind?	මම මොනවද අත්හැරියේ?
# What did Tom talk about?	ටොම් මොනවද කතා කලේ?
# What did the doctor say?	දොස්තර මොනවද කිව්වේ?
# What did the doctor say?	දොස්තර මොනවද කිව්වේ?
# What did you buy it for?	ඔබ එය මිලදී ගත්තේ කුමක් සඳහාද?
# What did you buy it for?	ඔබ එය මිලදී ගත්තේ කුමක් සඳහාද?
# What did you really see?	ඇත්තටම මොනවද දැක්කේ?
# What did you say to Tom?	ඔයා ටොම්ට මොනවද කිව්වේ?
# What did you talk about?	ඔයා මොනවද කතා කලේ?
# What did you talk about?	ඔයා මොනවද කතා කලේ?
# What did you talk about?	ඔයා මොනවද කතා කලේ?
# What did you want to do?	ඔයාට මොනවද කරන්න ඕන?
# What do you like to eat?	මොනවද කන්න කැමති?
# What do you need to buy?	ඔබ මිලදී ගත යුත්තේ කුමක්ද?
# What do you want to buy?	ඔබට මිලදී ගැනීමට අවශ්ය කුමක්ද?
# What do you want to buy?	ඔබට මිලදී ගැනීමට අවශ්ය කුමක්ද?
# What do you want to buy?	ඔබට මිලදී ගැනීමට අවශ්ය කුමක්ද?
# What do you want to eat?	මොනවද කන්න ඕනේ?
# What does USB stand for?	USB යනු කුමක්ද?
# What does he plan to do?	ඔහු කුමක් කිරීමට සැලසුම් කර තිබේද?
# What does he want to do?	ඔහුට මොනවද කරන්න ඕන?
# What does she look like?	ඇය මොන වගේද?
# What does she look like?	ඇය මොන වගේද?
# What does this pen cost?	මේ පෑනෙහි මිල කුමක් ද?
# What does this sign say?	මේ ලකුණෙන් කියන්නේ කුමක්ද?
# What else could it mean?	එයින් අදහස් කළ හැක්කේ වෙන කුමක් ද?
# What else does Tom need?	ටොම්ට වෙන මොනවද ඕන?
# What else does Tom want?	ටොම්ට වෙන මොනවද ඕන?
# What flight were you on?	ඔයා මොන ගුවන් යානයකද ගියේ?
# What flight were you on?	ඔයා මොන ගුවන් යානයකද ගියේ?
# What happened in Boston?	බොස්ටන් වල මොකද වුනේ?
# What happened on Monday?	සඳුදා කුමක් ද වුණේ?
# What happened to my bag?	මගේ බෑග් එකට මොකද උනේ?
# What has she done today?	අද ඇය මොනවද කළේ?
# What have you told them?	මොනවද ඔයා එයාලට කිව්වේ?
# What is aspirin made of?	ඇස්පිරින් සෑදෙන්නේ කුමක් ද?
# What is his nationality?	ඔහුගේ ජාතිකත්වය කුමක්ද?
# What is that over there?	එතන මොනවද තියෙන්නේ?
# What is your blood type?	ඔබේ රුධිර වර්ගය කුමක්ද?
# What is your blood type?	ඔබේ රුධිර වර්ගය කුමක්ද?
# What is your blood type?	ඔබේ රුධිර වර්ගය කුමක්ද?
# What is your occupation?	මොකක්ද ඔයාගේ රස්සාව?
# What is your waist size?	ඔයාගේ ඉණ ප්රමාණය මොකක්ද?
# What made you come here?	ඔයා මොනාද මෙහෙට ආවේ?
# What makes you think so?	ඔයා මොකද හිතන්නේ?
# What more does Tom need?	ටොම්ට තව මොනවද ඕන?
# What shall I begin with?	මම පටන් ගන්නේ මොනාද?
# What sort of play is it?	එය මොන වගේ සෙල්ලමක්ද?
# What teams were playing?	මොන කණ්ඩායම්ද සෙල්ලම් කළේ?
# What time did Tom leave?	ටොම් පිටත් වුණේ කීයටද?
# What time is Tom coming?	ටොම් එන්නෙ කීයටද?
# What time is Tom coming?	ටොම් එන්නෙ කීයටද?
# What time is it, anyway?	කොහොමත් වෙලාව කීයද?
# What time is it, anyway?	කොහොමත් වෙලාව කීයද?
# What time is the flight?	ගුවන් ගමනකට වේලාව කීයද?
# What time's your flight?	ඔබේ ගුවන් ගමන වේලාව කීයද?
# What was Tom doing here?	ටොම් මොනවද මෙතන කලේ?
# What was Tom's reaction?	ටොම්ගේ ප්රතිචාරය මොකක්ද?
# What was he doing there?	එයා එතන මොනවද කළේ?
# What was the boy called?	අර කොල්ලා මොකක්ද කිව්වේ?
# What was the difference?	මොකක්ද වෙනස?
# What were they drinking?	මොනවද එයාලා බොන්නේ?
# What were you two doing?	ඔයාලා දෙන්නා මොනවද කරන්නේ?
# What will become of her?	ඇයට කුමක් වේවිද?
# What year were you born?	ඔයා ඉපදුනේ මොන අවුරුද්දෙද?
# What year were you born?	ඔයා ඉපදුනේ මොන අවුරුද්දෙද?
# What year were you born?	ඔයා ඉපදුනේ මොන අවුරුද්දෙද?
# What you did is immoral.	ඔබ කළ දේ සදාචාර විරෝධීයි.
# What'll Tom do about it?	ටොම් ඒ ගැන කුමක් කරයි ද?
# What're you doing today?	අද මොනවද කරන්නේ?
# What're you waiting for?	ඔයා මොකටද බලන් ඉන්නේ?
# What's Tom's dog's name?	ටොම්ගෙ බල්ලගෙ නම මොකද්ද?
# What's causing that hum?	මොකක්ද ඒ හම්ප් එකට හේතුව?
# What's going on in here?	මෙතන මොකද වෙන්නේ?
# What's in that cupboard?	අර අල්මාරියේ මොනවද තියෙන්නේ?
# What's that bird called?	ඒ කුරුල්ලා මොකක්ද කියන්නේ?
# What's that bird called?	ඒ කුරුල්ලා මොකක්ද කියන්නේ?
# What's the airmail rate?	ගුවන් තැපැල් ගාස්තුව යනු කුමක්ද?
# What's the big surprise?	මොකක්ද ලොකුම පුදුමය?
# What's the next station?	ඊළඟ දුම්රිය ස්ථානය කුමක්ද?
# What's the next station?	ඊළඟ දුම්රිය ස්ථානය කුමක්ද?
# What's the problem, Tom?	මොකක්ද ප්රශ්නේ ටොම්?
# What's wrong with those?	මොනවද ඒ අයට වෙලා තියෙන්නේ?
# What's your aim in life?	ඔබේ ජීවිතයේ අරමුණ කුමක්ද?
# What's your maiden name?	මොකක්ද ඔයාගේ මුල් නම?
# What's your nationality?	ඔබේ ජාතිකත්වය කුමක්ද?
# What's your room number?	කාමර අංකය කුමක්ද?
# When did he arrive here?	කවද්ද එයා මෙහෙට ආවේ?
# When did you go to Rome?	කවද්ද රෝමයට ගියේ?
# When did you want to go?	ඔයාට කවද්ද යන්න ඕන වුනේ?
# When do you play tennis?	ඔයා කවදද ටෙනිස් ගහන්නේ?
# When do you play tennis?	ඔයා කවදද ටෙනිස් ගහන්නේ?
# When do you return home?	ඔයා කවද්ද ගෙදර එන්නේ?
# When should we tell Tom?	ටොම්ට අපි කවදද කියන්න ඕනේ?
# When was he here before?	ඔහු මීට කලින් මෙහෙ ආවේ කවද්ද?
# When will you come back?	ඔයා කවද්ද ආපහු එන්නේ?
# When will you come home?	ඔයා කවද්ද ගෙදර එන්නේ?
# Where are my cigarettes?	කෝ මගේ සිගරට් එක?
# Where are my sunglasses?	කෝ මගේ අව් කණ්ණාඩි?
# Where are my sunglasses?	කෝ මගේ අව් කණ්ණාඩි?
# Where are our umbrellas?	කෝ අපේ කුඩ?
# Where are the lifeboats?	ජීවිතාරක්ෂක බෝට්ටු කොහෙද?
# Where are we going next?	අපි කොහෙද ඊළඟට යන්නේ?
# Where are you going now?	දැන් කොහෙද යන්නේ?
# Where are you going now?	දැන් කොහෙද යන්නේ?
# Where are you right now?	දැන් කොහෙද ඔයා ඉන්නේ?
# Where are you taking us?	ඔයා අපිව කොහෙටද ගෙනියන්නේ?
# Where are you taking us?	ඔයා අපිව කොහෙටද ගෙනියන්නේ?
# Where are your car keys?	කෝ ඔයාගෙ කාර් එකේ යතුරු?
# Where are your children?	කෝ ඔයාගේ ළමයි?
# Where are your pictures?	කෝ උඹේ පින්තූර?
# Where can I buy a brush?	මට බුරුසුවක් මිලදී ගත හැක්කේ කොතැනින්ද?
# Where can I get the map?	සිතියම ලබාගත හැක්කේ කොතැනින්ද?
# Where can I get tickets?	මට ටිකට් ගන්න පුළුවන් කොහෙන්ද?
# Where can I park my car?	මගේ කාර් එක නවත්තන්න පුළුවන් කොහෙද?
# Where can you buy books?	පොත් මිලදී ගත හැක්කේ කොහෙන්ද?
# Where did Tom call from?	ටොම් කොහෙන්ද කතා කලේ?
# Where did you find this?	කොහෙන්ද මේක හොයාගත්තේ?
# Where did you hear that?	කොහෙන්ද ඔයාට ඒක ඇහුණේ?
# Where do they come from?	ඔවුන් කොහෙන්ද ආවේ?
# Where do you use French?	ඔබ ප්රංශ භාෂාව භාවිතා කරන්නේ කොහේද?
# Where do you want to go?	ඔයාට කොහෙද යන්න ඕන?
# Where do you want to go?	ඔයාට කොහෙද යන්න ඕන?
# Where does he come from?	කොහෙන්ද මෙයා ආවේ?
# Where does she live now?	දැන් ඇය ජීවත් වන්නේ කොහේද?
# Where does this book go?	මේ පොත කොහෙද යන්නේ?
# Where does this book go?	මේ පොත කොහෙද යන්නේ?
# Where does this book go?	මේ පොත කොහෙද යන්නේ?
# Where is he running now?	දැන් කොහෙද දුවන්නේ?
# Where is the toothpaste?	දන්තාලේප කොහෙද?
# Where is this guy going?	මේ මිනිහා කොහෙද යන්නේ?
# Where should I put this?	මම මේක දාන්න ඕනේ කොහෙද?
# Where was Tom yesterday?	ටොම් ඊයේ සිටියේ කොහේද?
# Where were you that day?	එදා ඔයා කොහෙද හිටියේ?
# Where's Tom going to be?	ටොම් කොහෙද ඉන්නේ?
# Where's Tom working now?	ටොම් දැන් වැඩ කරන්නේ කොහේද?
# Where's the book I need?	කෝ මට ඕන පොත?
# Where's the dining room?	කෑම කාමරය කොහෙද?
# Where's your father now?	දැන් ඔයාගේ තාත්තා කොහෙද?
# Which of these is yours?	මේ මොනවද ඔයාගෙ?
# Which one do you prefer?	ඔයා කැමති මොනවටද?
# Which one do you prefer?	ඔයා කැමති මොනවටද?
# Which skirt do you like?	මොන සායටද ඔයා කැමති?
# Which team won the game?	තරගය දිනුවේ මොන කණ්ඩායමද?
# Which way are you going?	ඔයා මොන පැත්තටද යන්නේ?
# Who are they talking to?	කාටද ඔවුන් කතා කරන්නේ?
# Who are those three men?	කවුද මේ මිනිස්සු තුන්දෙනා?
# Who are you hiding from?	ඔබ හැංගෙන්නෙ කාගෙන්ද?
# Who are you laughing at?	කාටද හිනාවෙන්නේ?
# Who are you looking for?	ඔයා හොයන්නේ කාවද?
# Who are you waiting for?	ඔබ බලා සිටින්නේ කා වෙනුවෙන්ද?
# Who are you waiting for?	ඔබ බලා සිටින්නේ කා වෙනුවෙන්ද?
# Who ate all the cookies?	කුකීස් කෑවේ කවුද?
# Who ate the last cookie?	අන්තිම කුකිය කෑවේ කවුද?
# Who caused the accident?	අනතුර සිදු කළේ කවුද?
# Who does that belong to?	කාටද අයිති ඒක?
# Who does this belong to?	කාටද මේක අයිති?
# Who does this belong to?	කාටද මේක අයිති?
# Who else have you asked?	වෙන කවුද ඔයා ඇහුවේ?
# Who else uses this room?	මේ කාමරය පාවිච්චි කරන්නේ කවුද?
# ...
# Tell me what your name is.	කියන්නකො ඔයාගේ නම මොකක්ද කියලා.
# Tell me where to put this.	මට කියන්න කොහෙන්ද මේක දාන්න ඕනේ කියලා.
# Tell me whose hat this is.	මට කියන්න මේ තොප්පිය කාගෙද කියලා.
# Tell me why she is crying.	මට කියන්න ඇයි එයා අඬන්නේ කියලා.
# Tell me why you came back.	කියන්න ඇයි ඔයා ආපහු ආවෙ කියලා.
# Tell them what I told you.	කියන්න මම ඔයාට කියපු දේ.
# Thank you for advising me.	මට උපදෙස් දුන්නට ස්තුතියි.
# Thank you for not smoking.	දුම් පානය නොකිරීම ගැන ස්තුතියි.
# Thank you for the flowers.	මල් වලට ස්තූතියි.
# Thank you for the present.	වර්තමානයට ස්තූතියි.
# Thank you for your advice.	ඔබගේ උපදෙස් වලට ස්තුතියි.
# Thank you very, very much!	බොහොම ස්තූතියි!
# Thanks for saving my hide.	මගේ හැංගිලා බේරුවට ස්තුතියි.
# Thanks for saving my life.	මගේ ජීවිතේ බේරුවට ස්තුතියි.
# Thanks for the correction.	නිවැරදි කිරීම සඳහා ස්තූතියි.
# Thanks for waiting for me.	මා එනතුරු බලා සිටීම ගැන ස්තුතියි.
# That big one is also mine.	ඒ ලොකු එකත් මගේ.
# That chimney is very high.	චිමිනිය ඉතා ඉහළයි.
# That didn't really happen.	ඒක ඇත්තටම වුණේ නැහැ.
# That disease is incurable.	ඒ ලෙඩේ සුව කළ නොහැකියි.
# That dog has a short tail.	ඒ බල්ලාට කෙටි වලිගයක් ඇත.
# That dog has a short tail.	ඒ බල්ලාට කෙටි වලිගයක් ඇත.
# That effort bore no fruit.	ඒ උත්සාහය ඵල දැරුවේ නැහැ.
# That fact can't be denied.	ඒ කාරණය ප්රතික්ෂේප කරන්න බැහැ.
# That film is for children.	මේ චිත්රපටය ළමයින් වෙනුවෙන්.
# That girl looks like Mary.	ඒ කෙල්ල මේරි වගේ.
# That girl looks like Mary.	ඒ කෙල්ල මේරි වගේ.
# That girl's eyes are blue.	ඒ කෙල්ලගේ ඇස් නිල් පාටයි.
# That hat matches the suit.	ඒ තොප්පිය ඇඳුමට ගැලපෙනවා.
# That house belongs to him.	ඒ නිවස අයිති ඔහුටයි.
# That house belongs to him.	ඒ නිවස අයිති ඔහුටයි.
# That is my mom's computer.	ඒ මගේ අම්මාගේ පරිගණකයයි.
# That is of no value to us.	ඒක අපිට වටින්නේ නෑ.
# That is rather unexpected.	එය තරමක් අනපේක්ෂිත ය.
# That is rather unexpected.	එය තරමක් අනපේක්ෂිත ය.
# That man has a foul mouth.	ඒ මනුස්සයට තියෙන්නේ කටවල්.
# That man has a foul mouth.	ඒ මනුස්සයට තියෙන්නේ කටවල්.
# That man was pestering me.	ඒ මනුස්සයා මට කරදර කළා.
# That might have been true.	ඒක ඇත්ත වෙන්න ඇති.
# That never happened to me.	මට කවදාවත් එහෙම දෙයක් වෙලා නෑ.
# That plan's bound to fail.	ඒ සැලසුම අසාර්ථක වෙයි.
# That scenario is unlikely.	එම තත්ත්වය විය නොහැක්කකි.
# That sounds like a threat.	ඒක තර්ජනයක් වගේ.
# That sounds pretty stupid.	ඒක හරිම මෝඩයි වගේ.
# That sounds very tempting.	එය ඉතා සිත් ඇදගන්නා සුළු බව පෙනේ.
# That street is very noisy.	ඒ වීදිය හරිම ඝෝෂාකාරීයි.
# That street is very noisy.	ඒ වීදිය හරිම ඝෝෂාකාරීයි.
# That tie is too expensive.	ඒ ටයි එක මිල අධිකයි.
# That tie really suits you.	ඒ ටයි එක ඇත්තටම ඔයාට ගැලපෙනවා.
# That was not my intention.	ඒක මගේ අරමුණ නෙවෙයි.
# That will never disappear.	ඒක කවදාවත් අතුරුදහන් වෙන්නේ නැහැ.
# That woman blocked my way.	ඒ ගෑනි මගේ පාර අවහිර කළා.
# That won't be good enough.	ඒක හොඳ මදි.
# That would be outstanding.	එය කැපී පෙනෙන වනු ඇත.
# That would be unfortunate.	එය අවාසනාවන්ත වනු ඇත.
# That wouldn't surprise me.	ඒක මාව පුදුම කරවන්නෙ නෑ.
# That'll cost thirty euros.	ඒ සඳහා යුරෝ තිහක් වැය වේ.
# That's a pretty big snake.	ඒ ලොකු සර්පයෙක්.
# That's a strange question.	ඒක අමුතු ප්රශ්නයක්.
# That's a very famous song.	ඒක බොහොම ජනප්රිය ගීතයක්.
# That's all I want to know.	එච්චරයි මට දැනගන්න ඕන.
# That's all we're offering.	එච්චරයි අපි ඉදිරිපත් කරන්නේ.
# That's between Tom and me.	ඒ ටොම් සහ මම අතර.
# That's it. I'm outta here.	ඒකනේ. මම මෙතනින් පිට ඉන්නේ.
# That's just what I wanted.	ඒක තමයි මට ඕන වුනේ.
# That's just what he needs.	ඒක තමයි එයාට අවශ්යය.
# That's my favorite excuse.	ඒක තමයි මගේ ප්රියතම නිදහසට කරුණ.
# That's my mom's chihuahua.	ඒ මගේ අම්මාගේ චිහුවාහුවා.
# That's my sister's camera.	ඒ මගේ නංගිගේ කැමරාව.
# That's no longer possible.	එය තවදුරටත් කළ නොහැකි ය.
# That's not what Tom meant.	ටොම් අදහස් කළේ එය නොවේ.
# That's one of the reasons.	ඒක එක හේතුවක්.
# That's the absolute truth.	ඒක තමයි පරම ඇත්ත.
# That's unlikely to happen.	එය සිදු නොවනු ඇත.
# That's very inconsiderate.	එය ඉතා නොසැලකිලිමත් ය.
# That's what I really want.	ඒක තමයි මට ඇත්තටම ඕන.
# That's what everyone does.	ඒක තමයි හැමෝම කරන්නේ.
# That's what sets us apart.	ඒක තමයි අපිව වෙන් කරන්නේ.
# The Allies wasted no time.	මිත්‍ර පාක්ෂිකයින් කාලය නාස්ති කළේ නැත.
# The Congress had no money.	කොංග්රසයට මුදල් තිබුණේ නැත.
# The War of 1812 had begun.	1812 යුද්ධය ආරම්භ විය.
# The answer is complicated.	උත්තරය සංකීර්ණයි.
# The answers are all right.	උත්තරේ හරි.
# The answers are all right.	උත්තරේ හරි.
# The apple is not yet ripe.	ඇපල් ගෙඩිය තවමත් ඉදුණු නැත.
# The audience looked bored.	ප්‍රේක්ෂකයන්ට කම්මැලි බවක් පෙනෙන්නට තිබුණි.
# The baby needs his mother.	දරුවාට ඔහුගේ මව අවශ්යයි.
# The baby needs its mother.	දරුවාට තම මව අවශ්ය වේ.
# The baby opened his mouth.	දරුවා කට ඇරියා.
# The baby was sound asleep.	බබාට හොඳටම නින්ද ගියා.
# The bell has not rung yet.	සීනුව තාම නාද වෙලා නෑ.
# The bigger man often wins.	ලොකු මිනිහා ගොඩක් වෙලාවට දිනනවා.
# The bird has not returned.	කුරුල්ලා ආපහු ආවේ නෑ.
# The bird spread its wings.	කුරුල්ලා පියාපත් විහිදුවයි.
# The blue car is expensive.	නිල් පාට කාර් එක මිල අධිකයි.
# The book is about the law.	පොත නීතිය ගැන.
# The book is too expensive.	පොත මිල අධිකයි.
# The boss said it's urgent!	ලොක්කා කිව්වා ඒක හදිසි වැඩක් කියලා!
# The bottle contained wine.	බෝතලයේ වයින් අඩංගු විය.
# The brake stopped working.	තිරිංග වැඩ නතර විය.
# The bread is old and hard.	පාන් පරණයි අමාරුයි.
# The bullet found its mark.	උණ්ඩය එහි සලකුණ සොයා ගත්තේය.
# The bus was heading north.	බස් එක උතුරට ගියා.
# The car moved very slowly.	වාහනය ඉතා සෙමින් ගමන් කළේය.
# The car was going forward.	කාර් එක ඉදිරියට ගියා.
# The cat is licking itself.	බළලා ලෙවකනවා.
# The cat ran after the rat.	බළලා මීයා පසුපස දිව ගියේය.
# The cat scratched my hand.	පූසා මගේ අත සීරීමට ලක් කළා.
# The chair is made of wood.	පුටුව ලී වලින් සාදා ඇත.
# The change was remarkable.	වෙනස කැපී පෙනෙන විය.
# The cheers were deafening.	ප්‍රීති ඝෝෂාව බිහිරි විය.
# The child fell out of bed.	දරුවා ඇඳෙන් වැටුණා.
# The child painted flowers.	දරුවා මල් පින්තාරු කළේය.
# The chili burnt my tongue.	මිරිස් මගේ දිව පිච්චුවා.
# The company went bankrupt.	සමාගම බංකොලොත් විය.
# The company went bankrupt.	සමාගම බංකොලොත් විය.
# The competition is fierce.	තරඟය දරුණුයි.
# The competition is fierce.	තරඟය දරුණුයි.
# The concert was a success.	ප්‍රසංගය සාර්ථක විය.
# The converse is also true.	ප්රතිචාරයත් ඇත්ත.
# The cook broiled the meat.	කෝකියා මස් තැම්බුවා.
# The countdown has started.	ගණන් කිරීම ආරම්භ වී ඇත.
# The cows are eating grass.	එළදෙනුන් තණකොළ කනවා.
# The crow spread his wings.	කපුටා තම පියාපත් විහිදුවයි.
# The crowd applauded again.	පිරිස නැවතත් අත්පොළසන් දුන්හ.
# The decision is not final.	තීරණය අවසාන නොවේ.
# The deer ran for its life.	මුවා තම ජීවිතය පතා දිව ගියේය.
# The default value is zero.	පෙරනිමි අගය ශුන්‍ය වේ.
# The doctor gave it to her.	වෛද්යවරයා එය ඇයට දුන්නේ ය.
# The doctor gave me a shot.	දොස්තර මට වෙඩි තිබ්බා.
# The dog chased the rabbit.	බල්ලා හාවා ලුහුබැඳ ගියේය.
# The dog is barking at Tom.	බල්ලා ටොම්ට බුරනවා.
# The dog ran after the cat.	බල්ලා බළලා පසුපස දිව ගියේය.
# The dog ran after the cat.	බල්ලා බළලා පසුපස දිව ගියේය.
# The dog sniffed the stick.	බල්ලා පොල්ල ආඝ්‍රාණය කළේය.
# The dog will not harm you.	බල්ලා ඔබට හානියක් නොකරයි.
# The dogs barked all night.	බල්ලෝ මුළු රෑම බුරනවා.
# The doll lay on the floor.	බෝනික්කා බිම වැතිර සිටියේය.
# The door handle is broken.	දොර හැන්ඩ්ල් එක කැඩිලා.
# The drains are blocked up.	කාණු අවහිර වී ඇත.
# The engine wouldn't start.	එන්ජිම ආරම්භ නොවේ.
# The famous pianist smiled.	සුප්‍රසිද්ධ පියානෝ වාදකයා සිනාසුණේය.
# The fence needed painting.	වැටට පින්තාරු කිරීම අවශ්ය විය.
# The food here is terrible.	මෙහි ආහාර ඉතා භයානකයි.
# The front door won't open.	ඉදිරිපස දොර විවෘත නොවේ.
# The funeral was yesterday.	අවසන් කටයුතු ඊයේ.
# The girl broke into tears.	කෙල්ල කඳුළු සැලුවා.
# The girl entered the room.	කෙල්ල කාමරේට ඇතුළු උනා.
# The girl has a soft heart.	කෙල්ලට මෘදු හදවතක් තියෙනවා.
# The girls danced to music.	කෙල්ලෝ සංගීතයට නැටුවා.
# The girls danced to music.	කෙල්ලෝ සංගීතයට නැටුවා.
# The glass is full of wine.	වීදුරුව වයින් වලින් පිරිලා.
# The guards didn't see Tom.	මුරකරුවන් ටොම්ව දැක්කේ නැහැ.
# The hail harmed the crops.	හිම කැට වැස්ස නිසා වගාවන්ට හානි සිදු විය.
# The haze enveloped London.	මීදුම ලන්ඩනය ආවරණය කළේය.
# The hen hatched five eggs.	කිකිළිය බිත්තර පහක් බිහි කළේය.
# The hospital is near here.	රෝහල මෙතන ළඟයි.
# The hotel was burned down.	හෝටලය ගිනිබත් විය.
# The hunter shot at a deer.	දඩයක්කාරයා මුවෙකුට වෙඩි තැබුවේය.
# The keys are on the table.	යතුරු මේසය මත ඇත.
# The keys are on the table.	යතුරු මේසය මත ඇත.
# The king abused his power.	රජතුමා බලය අයුතු ලෙස පාවිච්චි කළා.
# The kitchen is downstairs.	කුස්සිය පහළ මාලයේය.
# The kitten wants to sleep.	පූස් පැටියාට නිදාගන්න ඕන.
# The lemonade is too sweet.	ලෙමනේඩ් ඉතා මිහිරි ය.
# The lumber is still green.	දැව තවමත් කොළ පාටයි.
# The lunch is on the table.	දිවා ආහාරය මේසය මත ඇත.
# The man finally confessed.	අවසානයේ මිනිසා පාපොච්චාරණය කළේය.
# The matter is all settled.	කාරණය සියල්ල විසඳී ඇත.
# The meat is really tender.	මස් ඇත්තෙන්ම මෘදුයි.
# The meeting was held here.	රැස්වීම පැවැත්වුණේ මෙතැනදීය.
# The message was in French.	පණිවිඩය ප්රංශ භාෂාවෙන් විය.
# The milk is in the fridge.	කිරි ශීතකරණයේ ඇත.
# The monkey is in the cage.	වඳුරා කූඩුවේ සිටී.
# The monkey wants a banana.	වඳුරාට කෙසෙල් ගෙඩියක් ඕන.
# The news moved him deeply.	මෙම පුවත ඔහුව දැඩි ලෙස පෙලඹවූයේය.
# The odds are in his favor.	අවාසි ඔහුට පක්ෂව ඇත.
# The old man sat all alone.	මහළු මිනිසා තනියම වාඩි වී සිටියා.
# The old rules don't apply.	පැරණි නීති අදාළ නොවේ.
# The opera starts at seven.	ඔපෙරාව ආරම්භ වන්නේ හතට ය.
# The pain is getting worse.	වේදනාව තවත් නරක අතට හැරෙමින් තිබේ.
# The papers got blown away.	කඩදාසි පුපුරවා හැරියේය.
# The patient was in danger.	රෝගියා අනතුරේ.
# The phone started ringing.	දුරකථනය නාද වෙන්න පටන් ගත්තා.
# The phone stopped ringing.	දුරකථනය නාද වීම නතර විය.
# The phone stopped working.	දුරකථනය වැඩ කිරීම නතර කළේය.
# The plane arrived on time.	යානය නියමිත වේලාවට පැමිණියේය.
# The plane increased speed.	ගුවන්යානයේ වේගය වැඩි වුණා.
# The pond is 3 meters deep.	පොකුණ මීටර් 3 ක් ගැඹුරු ය.
# The population is growing.	ජනගහනය වැඩි වෙනවා.
# The population is growing.	ජනගහනය වැඩි වෙනවා.
# The post office is closed.	තැපැල් කාර්යාලය වසා ඇත.
# The price isn't important.	මිල වැදගත් නැහැ.
# The price of meat dropped.	මස් මිල පහත වැටුණා.
# The prisoner was released.	සිරකරුවා නිදහස් විය.
# The problem perplexed him.	ගැටලුව ඔහුව ව්‍යාකූල කළේය.
# The prophecy came to pass.	අනාවැකිය ඉටු විය.
# The question was answered.	ප්රශ්නයට පිළිතුරු ලැබුණි.
# The rain lasted five days.	වැස්ස දවස් පහක් තිබ්බා.
# The rain lasted four days.	වැස්ස දවස් හතරක් තිබ්බා.
# The road turns left there.	පාර වමට හැරෙනවා එතනට.
# The school is on the hill.	පාසල තියෙන්නේ කන්ද උඩ.
# The shop did not want him.	කඩේට එයාව ඕන වුනේ නෑ.
# The shop did not want him.	කඩේට එයාව ඕන වුනේ නෑ.
# The shop did not want him.	කඩේට එයාව ඕන වුනේ නෑ.
# The shop did not want him.	කඩේට එයාව ඕන වුනේ නෑ.
# The situation is critical.	තත්වය තීරණාත්මක ය.
# The situation is hopeless.	තත්වය බලාපොරොත්තු රහිත ය.
# The sky started to darken.	අහස අඳුරු වෙන්න පටන් ගත්තා.
# The snow lasted four days.	හිම දින හතරක් පැවතුනි.
# The soldier acted bravely.	සොල්දාදුවා නිර්භීතව ක්රියා කළා.
# The soldier gave his name.	සොල්දාදුවා ඔහුගේ නම සඳහන් කළේය.
# The soldier is going away.	සොල්දාදුවා යනවා.
# The spy burned the papers.	ඔත්තුකරු කඩදාසි පුළුස්සා දැමීය.
# The station is dead ahead.	දුම්රිය ස්ථානය ඉදිරියෙන් මිය ගොස් ඇත.
# The station is pretty far.	දුම්රිය ස්ථානය බොහෝ දුරයි.
# The stew smells delicious.	ඉස්ටුවක් රසවත් සුවඳයි.
# The store closes at seven.	ගබඩාව හතට වැසෙයි.
# The street lights went on.	වීදි පහන් දැල්වීය.
# The sun has not risen yet.	හිරු තවම නැගෙන්නේ නැහැ.
# The surgery was a success.	සැත්කම සාර්ථක විය.
# The temperature is rising.	උෂ්ණත්වය ඉහළ යනවා.
# The thunder became louder.	ගිගුරුම් වැඩි විය.
# The train arrived on time.	දුම්රිය නියමිත වේලාවට පැමිණියේය.
# The train arrived on time.	දුම්රිය නියමිත වේලාවට පැමිණියේය.
# The train finally arrived.	අන්තිමේදි කෝච්චිය ආවා.
# The train has two engines.	දුම්රියේ එන්ජින් දෙකක් ඇත.
# The train hasn't come yet.	කෝච්චිය තාම ආවේ නෑ.
# The train is packed today.	අද කෝච්චිය අසුරා ඇත.
# The tree blocked the road.	ගස මාර්ගය අවහිර කළේය.
# The tree blocked the road.	ගස මාර්ගය අවහිර කළේය.
# The war broke out in 1939.	1939 දී යුද්ධය ආරම්භ විය.
# The war is still going on.	යුද්ධය තවමත් සිදුවෙමින් පවතී.
# The weather turned better.	කාලගුණය යහපත් අතට හැරුණි.
# The weather was very good.	කාලගුණයත් ගොඩක් හොඳයි.
# The wind blew her hat off.	සුළඟ ඇගේ තොප්පිය ඉවතට විසිවී ගියේය.
# The woman hugged the baby.	කාන්තාව දරුවා වැළඳ ගත්තාය.
# The workers are on strike.	කම්කරුවන් වැඩ වර්ජනයක.
# The world has five oceans.	ලෝකයේ සාගර පහක් ඇත.
# The worst is already over.	නරකම දේ දැනටමත් අවසන්.
# The wound became infected.	තුවාලය ආසාදනය වී ඇත.
# The years pass by quickly.	වසර ඉක්මනින් ගෙවී යයි.
# Their fates were entwined.	ඔවුන්ගේ ඉරණම පැටලී තිබුණි.
# Their price is below ours.	ඒවායේ මිල අපට වඩා අඩුය.
# Their wedding is tomorrow.	ඔවුන්ගේ විවාහය හෙට.
# There are no clean plates.	පිරිසිදු තහඩු නොමැත.
# There are no comments yet.	තවම අදහස් නැහැ.
# There are no easy answers.	ලේසි උත්තරයක් නෑ.
# There are three survivors.	දිවි ගලවා ගත් තිදෙනෙක් සිටිති.
# There is a letter for you.	ඔයාට ලියුමක් තියෙනවා.
# There is a letter for you.	ඔයාට ලියුමක් තියෙනවා.
# There is food on the desk.	මේසය මත ආහාර තිබේ.
# There is little time left.	තව ටික කාලයක් ඉතුරුයි.
# There is little wine left.	වයින් ටිකක් ඉතුරුයි.
# There is no TV in my room.	මගේ කාමරේ ටීවී එකක් නෑ.
# There is no running water.	ගලා යන ජලය නැත.
# There isn't any milk left.	කිරි ඉතුරු වෙලා නෑ.
# There was another problem.	තවත් ප්රශ්නයක් තිබුණා.
# There was much work to do.	කරන්න වැඩ ගොඩක් තිබුණා.
# There was nobody in there.	එහි කිසිවෙක් සිටියේ නැත.
# There was not enough fuel.	ඉන්ධන ප්රමාණවත් නොවීය.
# There was nowhere to hide.	හැංගෙන්න තැනක් තිබුණේ නැහැ.
# There was nowhere to hide.	හැංගෙන්න තැනක් තිබුණේ නැහැ.
# There wasn't anyone there.	එහි කිසිවෙක් සිටියේ නැත.
# There wasn't much traffic.	වැඩි වාහන තදබදයක් තිබුණේ නැහැ.
# There were lots of people.	ගොඩක් අය හිටියා.
# There were so many people.	ගොඩක් අය හිටියා.
# There's a book on my desk.	මගේ මේසය මත පොතක් ඇත.
# There's a hair in my soup.	මගේ සුප් එකේ කොණ්ඩයක් තියෙනවා.
# There's a hair in my soup.	මගේ සුප් එකේ කොණ්ඩයක් තියෙනවා.
# There's a hole in my coat.	මගේ කබායෙහි සිදුරක් ඇත.
# There's a lot on the line.	රේඛාවේ බොහෝ දේ ඇත.
# There's a map on the wall.	බිත්තියේ සිතියමක් තියෙනවා.
# There's a message for you.	ඔයාට පණිවිඩයක් තියෙනවා.
# There's a restaurant here.	මෙතන අවන්හලක් තියෙනවා.
# There's a rock in my shoe.	සපත්තුවේ ගලක් තියෙනවා.
# There's a rock in my shoe.	සපත්තුවේ ගලක් තියෙනවා.
# There's a serious problem.	බරපතල ප්රශ්නයක් තියෙනවා.
# There's dust on the table.	මේසේ දූවිලි තියෙනවා.
# There's just one day left.	තව එක දවසක් විතරයි ඉතුරු වෙලා තියෙන්නේ.
# There's no other solution.	වෙන විසඳුමක් නැහැ.
# There's not enough coffee.	කෝපි මදි.
# There's nothing in my cup.	මගේ කෝප්පයේ මුකුත් නෑ.
# There's nothing we can do.	අපිට කරන්න දෙයක් නෑ.
# There's one small problem.	පොඩි ප්රශ්නයක් තියෙනවා.
# There's something in here.	මෙතන මොකක් හරි තියෙනවා.
# There's something in here.	මෙතන මොකක් හරි තියෙනවා.
# There's something missing.	යමක් අතුරුදහන්.
# There's still a lot to do.	තව කරන්න ගොඩක් දේවල් තියෙනවා.
# There's too much at stake.	පරදුවට තියන තරම් දේවල් තියෙනවා.
# These are Tom's ski boots.	මේවා ටොම්ගේ ස්කී බූට් ය.
# These are difficult times.	මේවා දුෂ්කර කාලයන්ය.
# These boots are expensive.	මෙම සපත්තු මිල අධිකයි.
# These boots belong to her.	මෙම සපත්තු ඇයට අයත් වේ.
# These oranges have rotted.	මෙම දොඩම් කුණු වී ඇත.
# These oranges have rotted.	මෙම දොඩම් කුණු වී ඇත.
# These plates aren't clean.	මෙම තහඩු පිරිසිදු නොවේ.
# These shoes are too small.	සපත්තු හරිම පුංචියි.
# These shoes are too tight.	සපත්තු තද වැඩියි.
# These socks are a bargain.	මෙම මේස් කේවල් කිරීමකි.
# These trees are beautiful.	මේ ගස් ටික ලස්සනයි.
# They agreed on everything.	ඔවුන් හැම දේටම එකඟ වුණා.
# They amended the document.	ඔවුන් ලේඛනය සංශෝධනය කළා.
# They are baseball players.	ඔවුන් බේස්බෝල් ක්රීඩකයෝ.
# They are both in the room.	දෙන්නම කාමරේ.
# They are crazy about jazz.	එයාලට ජෑස් ගැන පිස්සු.
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# #split each line of text file into English and Sinhala translations

# %%
import pandas as pd
import random


path = '/content/drive/MyDrive/CSV/englishsinhala.txt'
df = pd.read_table(path, sep="\t")


text_pairs = []
for index, row in df.iterrows():
    english = row['english']
    sinhala = "[start] " + row['sinhala'] + " [end]"
    text_pairs.append((english, sinhala))


for i in range(3):
    print(random.choice(text_pairs))
# Out:
# ('He robbed me of my bag.', '[start] එයා මගේ බෑග් එක කොල්ල කෑවා. [end]')
# ('I think Tom is working now.', '[start] මම හිතන්නේ ටොම් දැන් වැඩ කරනවා. [end]')
# ('Is this it?', '[start] මේ ඒකද? [end]')

# %% [markdown]
# #Randomize the Data

# %%
import random


random.shuffle(text_pairs)

for i in range(3):
    print(random.choice(text_pairs))
# Out:
# ("It actually wasn't that bad.", '[start] ඇත්තටම ඒක එච්චර නරක නෑ. [end]')
# ('It uses solar power.', '[start] එය සූර්ය බලය භාවිතා කරයි. [end]')
# ('I wish I could help you.', '[start] මම කැමතියි ඔයාට උදව් කරන්න. [end]')

# %% [markdown]
# #Spliting the data into training, validation and Testing

# %%
num_val_samples = int(0.15 * len(text_pairs))
num_test_samples = int(0.15 * len(text_pairs))
num_train_samples = len(text_pairs) - num_val_samples - num_test_samples


train_pairs = text_pairs[:num_train_samples]
val_pairs = text_pairs[num_train_samples:num_train_samples + num_val_samples]
test_pairs = text_pairs[num_train_samples + num_val_samples:]


print("Total sentences:", len(text_pairs))
print("Training set size:", len(train_pairs))
print("Validation set size:", len(val_pairs))
print("Testing set size:", len(test_pairs))
# Out:
# Total sentences: 44377
# Training set size: 31065
# Validation set size: 6656
# Testing set size: 6656

# %% [markdown]
# #Removing Punctuations

# %%
import string
import re

strip_chars = string.punctuation + "¿"
strip_chars = strip_chars.replace("[", "")
strip_chars = strip_chars.replace("]", "")

translation_table = str.maketrans("", "", strip_chars)

cleaned_english_lines = [line.translate(translation_table) for line in df['english']]

cleaned_sinhala_lines = [line.translate(translation_table) for line in df['sinhala']]

for i in range(min(20, len(cleaned_english_lines))):
    print("English:", cleaned_english_lines[i])
    print("Sinhala:", cleaned_sinhala_lines[i])
    print()
# Out:
# English: Go
# Sinhala: යන්න
#
# English: Go
# Sinhala: යන්න
#
# English: Go
# Sinhala: යන්න
#
# English: Go
# Sinhala: යන්න
#
# English: Hi
# Sinhala: ආයුබෝවන්
#
# English: Run
# Sinhala: දුවන්න
#
# English: Run
# Sinhala: දුවන්න
#
# English: Who
# Sinhala: WHO
#
# English: Fire
# Sinhala: ගිනි
#
# English: Fire
# Sinhala: ගිනි
#
# English: Fire
# Sinhala: ගිනි
#
# English: Help
# Sinhala: උදව්
#
# English: Help
# Sinhala: උදව්
#
# English: Help
# Sinhala: උදව්
#
# English: Jump
# Sinhala: පනින්න
#
# English: Jump
# Sinhala: පනින්න
#
# English: Stop
# Sinhala: නවත්වන්න
#
# English: Stop
# Sinhala: නවත්වන්න
#
# English: Stop
# Sinhala: නවත්වන්න
#
# English: Wait
# Sinhala: ඉන්න

# %% [markdown]
# #Find the vocabulary size and sequence length

# %%
import numpy as np


english_sentences = [pair[0] for pair in text_pairs]
sinhala_sentences = [pair[1] for pair in text_pairs]


all_sentences = english_sentences + sinhala_sentences

sequence_lengths = [len(seq.split()) for seq in all_sentences]
max_sequence_length = max(sequence_lengths)
mean_sequence_length = np.mean(sequence_lengths)


tokenizer = keras.preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(all_sentences)


vocab_size = len(tokenizer.word_index) + 1

print("Vocabulary Size:", vocab_size)
print("Max Sequence Length:", max_sequence_length)
print("Mean Sequence Length:", mean_sequence_length)
# Out:
# Vocabulary Size: 22512
# Max Sequence Length: 47
# Mean Sequence Length: 5.823196700993758

# %% [markdown]
# #Vectorizing the English and Sinhala text pairs

# %%
import tensorflow as tf


def custom_standardization(input_string):
    lowercase = tf.strings.lower(input_string)
    return tf.strings.regex_replace(lowercase, f"[{re.escape(strip_chars)}]", "")


vocab_size = 22512
sequence_length = 47

source_vectorization = layers.TextVectorization(
    max_tokens=vocab_size,
    output_mode="int",
    output_sequence_length=sequence_length,
)
target_vectorization = layers.TextVectorization(
    max_tokens=vocab_size,
    output_mode="int",
    output_sequence_length=sequence_length + 1,
    standardize=custom_standardization,
)


train_english_texts = [pair[0] for pair in train_pairs]
train_sinhala_texts = [pair[1] for pair in train_pairs]


source_vectorization.adapt(train_english_texts)
target_vectorization.adapt(train_sinhala_texts)

# %% [markdown]
# #Preparing datasets for the translation task

# %%
import tensorflow as tf


batch_size = 64


def format_dataset(eng, sinhala):
    eng = source_vectorization(eng)
    sinhala = target_vectorization(sinhala)
    return ({
        "english": eng,
        "sinhala": sinhala[:, :-1],
    }, sinhala[:, 1:])


def make_dataset(pairs):
    eng_texts, sinhala_texts = zip(*pairs)
    eng_texts = list(eng_texts)
    sinhala_texts = list(sinhala_texts)
    dataset = tf.data.Dataset.from_tensor_slices((eng_texts, sinhala_texts))
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(format_dataset, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    return dataset.shuffle(2048).prefetch(tf.data.experimental.AUTOTUNE).cache()

train_ds = make_dataset(train_pairs)
val_ds = make_dataset(val_pairs)


for inputs, targets in train_ds.take(1):
    print(f"inputs['english'].shape: {inputs['english'].shape}")
    print(f"inputs['sinhala'].shape: {inputs['sinhala'].shape}")
    print(f"targets.shape: {targets.shape}")


print(list(train_ds.as_numpy_iterator())[0])
# Out:
# inputs['english'].shape: (64, 47)
# inputs['sinhala'].shape: (64, 47)
# targets.shape: (64, 47)
# ({'english': array([[ 23, 313,  51, ...,   0,   0,   0],
#        [ 10, 206, 266, ...,   0,   0,   0],
#        [ 22, 265, 843, ...,   0,   0,   0],
#        ...,
#        [192,  30,   6, ...,   0,   0,   0],
#        [ 22, 199,  26, ...,   0,   0,   0],
#        [ 25,  13,   3, ...,   0,   0,   0]]), 'sinhala': array([[   2,   11,  412, ...,    0,    0,    0],
#        [   2,    9,  612, ...,    0,    0,    0],
#        [   2,    8,   29, ...,    0,    0,    0],
#        ...,
#        [   2,  599, 1368, ...,    0,    0,    0],
#        [   2,  156, 1317, ...,    0,    0,    0],
#        [   2,   86,   17, ...,    0,    0,    0]])}, array([[  11,  412, 2680, ...,    0,    0,    0],
#        [   9,  612,   56, ...,    0,    0,    0],
#        [   8,   29,  718, ...,    0,    0,    0],
#        ...,
#        [ 599, 1368, 3631, ...,    0,    0,    0],
#        [ 156, 1317,   36, ...,    0,    0,    0],
#        [  86,   17,  265, ...,    0,    0,    0]]))

# %% [markdown]
# #Transformer encoder implemented as a subclassed Layer

# %%
class TransformerEncoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim)
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation="relu"),
             layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()

    def call(self, inputs, mask=None):
        if mask is not None:
            mask = mask[:, tf.newaxis, :]
        attention_output = self.attention(
            inputs, inputs, attention_mask=mask)
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)

    def get_config(self):
        config = super().get_config()
        config.update({
            "embed_dim": self.embed_dim,
            "num_heads": self.num_heads,
            "dense_dim": self.dense_dim,
        })
        return config

# %% [markdown]
# #Transformer decoder

# %%
class TransformerDecoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim)
        self.attention_2 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim)
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation="relu"),
             layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()
        self.supports_masking = True

    def get_config(self):
        config = super().get_config()
        config.update({
            "embed_dim": self.embed_dim,
            "num_heads": self.num_heads,
            "dense_dim": self.dense_dim,
        })
        return config

    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, sequence_length = input_shape[0], input_shape[1]
        i = tf.range(sequence_length)[:, tf.newaxis]
        j = tf.range(sequence_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat(
            [tf.expand_dims(batch_size, -1),
             tf.constant([1, 1], dtype=tf.int32)], axis=0)
        return tf.tile(mask, mult)

    def call(self, inputs, encoder_outputs, mask=None):
        causal_mask = self.get_causal_attention_mask(inputs)
        if mask is not None:
            padding_mask = tf.cast(
                mask[:, tf.newaxis, :], dtype="int32")
            padding_mask = tf.minimum(padding_mask, causal_mask)
        else:
            padding_mask = mask
        attention_output_1 = self.attention_1(
            query=inputs,
            value=inputs,
            key=inputs,
            attention_mask=causal_mask)
        attention_output_1 = self.layernorm_1(inputs + attention_output_1)
        attention_output_2 = self.attention_2(
            query=attention_output_1,
            value=encoder_outputs,
            key=encoder_outputs,
            attention_mask=padding_mask,
        )
        attention_output_2 = self.layernorm_2(
            attention_output_1 + attention_output_2)
        proj_output = self.dense_proj(attention_output_2)
        return self.layernorm_3(attention_output_2 + proj_output)

# %% [markdown]
# #Positional Encoding

# %%
class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, vocab_size, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.token_embeddings = layers.Embedding(
            input_dim=vocab_size, output_dim=embed_dim)
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=embed_dim)
        self.sequence_length = sequence_length
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs)
        embedded_positions = self.position_embeddings(positions)
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)

    def get_config(self):
        config = super().get_config()
        config.update({
            "vocab_size": self.vocab_size,
            "embed_dim": self.embed_dim,
            "sequence_length": self.sequence_length,
        })
        return config

# %% [markdown]
# #End-to-end Transformer model

# %%
embed_dim = 256
dense_dim = 2048
num_heads = 8

encoder_inputs = keras.Input(shape=(None,), dtype="int64", name="english")
decoder_inputs = keras.Input(shape=(None,), dtype="int64", name="sinhala")

encoder_embedding_layer = PositionalEmbedding(sequence_length, vocab_size, embed_dim)
decoder_embedding_layer = PositionalEmbedding(sequence_length, vocab_size, embed_dim)

encoder_embedded_inputs = encoder_embedding_layer(encoder_inputs)
decoder_embedded_inputs = decoder_embedding_layer(decoder_inputs)

encoder_outputs = TransformerEncoder(embed_dim, dense_dim, num_heads)(encoder_embedded_inputs)

decoder_outputs = TransformerDecoder(embed_dim, dense_dim, num_heads)(decoder_embedded_inputs, encoder_outputs)

decoder_outputs = layers.Dropout(0.5)(decoder_outputs)
decoder_outputs = layers.Dense(vocab_size, activation="softmax")(decoder_outputs)

transformer_model = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)

transformer_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  english (InputLayer)        [(None, None)]               0         []
#
#  sinhala (InputLayer)        [(None, None)]               0         []
#
#  positional_embedding (Posi  (None, None, 256)            5775104   ['english[0][0]']
#  tionalEmbedding)
#
#  positional_embedding_1 (Po  (None, None, 256)            5775104   ['sinhala[0][0]']
#  sitionalEmbedding)
#
#  transformer_encoder (Trans  (None, None, 256)            3155456   ['positional_embedding[0][0]']
#  formerEncoder)
#
#  transformer_decoder (Trans  (None, None, 256)            5259520   ['positional_embedding_1[0][0]
#  formerDecoder)                                                     ',
#                                                                      'transformer_encoder[0][0]']
#
#  dropout (Dropout)           (None, None, 256)            0         ['transformer_decoder[0][0]']
#
#  dense_4 (Dense)             (None, None, 22512)          5785584   ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 25750768 (98.23 MB)
# Trainable params: 25750768 (98.23 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# #Training the sequence-to-sequence Transformer

# %%
transformer_model.compile(
    optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

transformer_model.fit(train_ds, epochs=15, validation_data=val_ds)
# Out:
# Epoch 1/15
# 486/486 [==============================] - 90s 169ms/step - loss: 4.8616 - accuracy: 0.3920 - val_loss: 4.0861 - val_accuracy: 0.4505
# Epoch 2/15
# 486/486 [==============================] - 79s 163ms/step - loss: 3.7834 - accuracy: 0.4824 - val_loss: 3.4698 - val_accuracy: 0.5200
# Epoch 3/15
# 486/486 [==============================] - 77s 158ms/step - loss: 3.2312 - accuracy: 0.5404 - val_loss: 3.1500 - val_accuracy: 0.5554
# Epoch 4/15
# 486/486 [==============================] - 77s 158ms/step - loss: 2.8648 - accuracy: 0.5790 - val_loss: 2.9773 - val_accuracy: 0.5743
# Epoch 5/15
# 486/486 [==============================] - 77s 158ms/step - loss: 2.5903 - accuracy: 0.6103 - val_loss: 2.8283 - val_accuracy: 0.5939
# Epoch 6/15
# 486/486 [==============================] - 79s 163ms/step - loss: 2.3738 - accuracy: 0.6364 - val_loss: 2.7592 - val_accuracy: 0.6063
# Epoch 7/15
# 486/486 [==============================] - 77s 158ms/step - loss: 2.2046 - accuracy: 0.6583 - val_loss: 2.7741 - val_accuracy: 0.6057
# Epoch 8/15
# 486/486 [==============================] - 79s 163ms/step - loss: 2.0702 - accuracy: 0.6771 - val_loss: 2.7238 - val_accuracy: 0.6168
# Epoch 9/15
# 486/486 [==============================] - 77s 158ms/step - loss: 1.9695 - accuracy: 0.6918 - val_loss: 2.6999 - val_accuracy: 0.6233
# Epoch 10/15
# 486/486 [==============================] - 77s 158ms/step - loss: 1.8878 - accuracy: 0.7060 - val_loss: 2.6756 - val_accuracy: 0.6303
# Epoch 11/15
# 486/486 [==============================] - 77s 158ms/step - loss: 1.8261 - accuracy: 0.7162 - val_loss: 2.7018 - val_accuracy: 0.6291
# Epoch 12/15
# 486/486 [==============================] - 77s 158ms/step - loss: 1.7777 - accuracy: 0.7251 - val_loss: 2.7277 - val_accuracy: 0.6320
# Epoch 13/15
# 486/486 [==============================] - 77s 158ms/step - loss: 1.7419 - accuracy: 0.7326 - val_loss: 2.6971 - val_accuracy: 0.6363
# Epoch 14/15
# 486/486 [==============================] - 77s 158ms/step - loss: 1.7164 - accuracy: 0.7392 - val_loss: 2.7259 - val_accuracy: 0.6391
# Epoch 15/15
# 486/486 [==============================] - 77s 158ms/step - loss: 1.6897 - accuracy: 0.7460 - val_loss: 2.7129 - val_accuracy: 0.6412

# %% [markdown]
# #Generate random sentences & translate

# %%
sinhala_vocab = target_vectorization.get_vocabulary()


sinhala_index_lookup = dict(zip(range(len(sinhala_vocab)), sinhala_vocab))

# %%
import numpy as np

max_decoded_sentence_length = 20

def decode_sequence(input_sentence):
    tokenized_input_sentence = source_vectorization([input_sentence])
    decoded_sentence = "[start]"
    for i in range(max_decoded_sentence_length):
        tokenized_target_sentence = target_vectorization([decoded_sentence])[:, :-1]
        predictions = transformer_model.predict([tokenized_input_sentence, tokenized_target_sentence])
        sampled_token_index = np.argmax(predictions[0, i, :])
        sampled_token = sinhala_index_lookup[sampled_token_index]
        decoded_sentence += " " + sampled_token
        if sampled_token == "[end]":
            break
    return decoded_sentence

test_eng_texts = [pair[0] for pair in test_pairs]
for _ in range(20):
    input_sentence = random.choice(test_eng_texts)
    print("-")
    print("English input:", input_sentence)
    translated_sentence = decode_sequence(input_sentence)
    print("Translated Sinhala:", translated_sentence)
# Out:
# -
# English input: These glasses are cool.
# 1/1 [==============================] - 1s 557ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# Translated Sinhala: [start] මේ පොත රිදෙනවා [end]
# -
# English input: I saw him looking at me.
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Translated Sinhala: [start] මම දැක්කා එයා මං දිහා බලාගෙන ඉන්නවා [end]
# -
# English input: Tom isn't wearing socks.
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Translated Sinhala: [start] ටොම් සුදු ජැකට් එකක් නැහැ [end]
# -
# English input: He lives alone in the woods.
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Translated Sinhala: [start] ඔහු ජීවත් වන්නේ තනියම [end]
# -
# English input: Where should I put this?
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Translated Sinhala: [start] මම කොහෙද මේක දාන්න ඕන [end]
# -
# English input: It's so beautiful.
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Translated Sinhala: [start] ඒක හරිම ලස්සනයි [end]
# -
# English input: He blackmailed me.
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Translated Sinhala: [start] එයා මට මාව ඉන්නම් [end]
# -
# English input: Look away.
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Translated Sinhala: [start] එය බලන්න [end]
# -
# English input: You're clever.
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 36ms/step
# Translated Sinhala: [start] ඔයා දක්ෂයි [end]
# -
# English input: I didn't have time for that.
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Translated Sinhala: [start] මට ඒක කාලය තිබුණේ නැහැ [end]
# -
# English input: Tom is their leader.
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Translated Sinhala: [start] ටොම් ඔවුන්ගේ එකම ඔවුන්ගේ ය [end]
# -
# English input: I love this song.
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Translated Sinhala: [start] මම මේ කාර් එක ආසයි [end]
# -
# English input: Don't work too hard!
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 39ms/step
# Translated Sinhala: [start] වෙහෙස මහන්සි වී වැඩ කරන්න එපා [end]
# -
# English input: He looked up at the sky.
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 35ms/step
# Translated Sinhala: [start] ඔහු අහස දෙස බැලුවේය [end]
# -
# English input: She called for help.
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# Translated Sinhala: [start] ඇය උදව් කිරීමට උදව් කළාය [end]
# -
# English input: Each student has a locker.
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# Translated Sinhala: [start] සෑම භාවිතා වේ [end]
# -
# English input: Could you walk the dog?
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# Translated Sinhala: [start] ඔබට බල්ලා එළියට යන්න පුළුවන්ද [end]
# -
# English input: Tom is cutting the bread.
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 22ms/step
# Translated Sinhala: [start] ටොම් පාන් කනවා [end]
# -
# English input: Don't worry about your work.
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Translated Sinhala: [start] ඔබේ වැඩ ගැන කරදර කරන්න එපා [end]
# -
# English input: She can't afford it.
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# Translated Sinhala: [start] ඇයට එය දරාගන්න බැහැ [end]
